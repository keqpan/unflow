# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/InteriorNet_5.1m/ \
--name intnet_unflow_bigL_no_idtA_syn_holes\
--gpu_ids 1,2\
--batch_size 6\
--model unflow_gan\
--crop_size_h 256\
--crop_size_w 256\
--load_size_h 640\
--load_size_w 480\
--num_iter_gen 3\
--disc_for_normals\
--disc_for_depth\
--use_spnorm\
--use_cycle_B\
--l_depth_A_begin 2\
--l_depth_A_end 2\
--l_depth_B_begin 2\
--l_depth_B_end 2\
--l_cycle_B_begin 2\
--l_cycle_B_end 2\
--l_identity 1.0\
--no_idt_A\
--l_normal 0.3 \
--data_shuffle\
--max_dataset_size 60000\
--init_type xavier\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 5\
--n_epochs 50\
--n_epochs_decay 250\
--norm_d none \
--inp_B img_depth \
--netD n_layers
# Out:
# ----------------- Options ---------------
#                batch_size: 6                             	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 256                           	[default: 240]
#               crop_size_w: 256                           	[default: 320]
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/InteriorNet_5.1m/	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: True                          	[default: False]
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 1,2
#               hole_border: -0.98
#             img2depth_dir: ./checkpoints/img2d_pretrain/
#                  img_freq: 40                            	[default: 1]
#                 init_type: xavier
#                     inp_B: img_depth                     	[default: depth]
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0
#             l_cycle_A_end: 10.0
#           l_cycle_B_begin: 2.0                           	[default: 10.0]
#             l_cycle_B_end: 2.0                           	[default: 10.0]
#           l_depth_A_begin: 2.0                           	[default: 5.0]
#             l_depth_A_end: 2.0                           	[default: 0.0]
#           l_depth_B_begin: 2.0                           	[default: 5.0]
#             l_depth_B_end: 2.0                           	[default: 0.0]
#                  l_hole_A: 0.0
#                l_identity: 1.0                           	[default: 0.0]
#                l_max_iter: 5000
#                  l_mean_A: 0.0
#                  l_mean_B: 0.0
#                  l_normal: 0.3                           	[default: 10.0]
#                l_num_iter: 5000
# l_reconstruction_semantic: 0.0
#                    l_tv_A: 0.0
#                load_epoch: last
#      load_epoch_img2depth: last
#        load_epoch_weights: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 640                           	[default: 480]
#               load_size_w: 480                           	[default: 640]
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 60000                         	[default: inf]
#              max_distance: 5100.0
#                     model: unflow_gan                    	[default: semi_cycle_gan]
#                  n_blocks: 9
#            n_downsampling: 2
#                  n_epochs: 50                            	[default: 1]
#            n_epochs_decay: 250                           	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: intnet_unflow_bigL_no_idtA_syn_holes	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32
#                   ngf_img: 32
#           ngf_img_feature: 32
#                  no_idt_A: True                          	[default: False]
#                      norm: group
#                    norm_d: none                          	[default: instance]
#              num_iter_dis: 1
#              num_iter_gen: 3                             	[default: 1]
#               num_workers: 4
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 5                             	[default: 10]
#           upsampling_type: transpose
#               use_cycle_A: False
#               use_cycle_B: True                          	[default: False]
#         use_mean_matching: False
#    use_pretrain_img2depth: False
#      use_pretrain_weights: False
#              use_semantic: False
#      use_semi_cycle_first: False
#     use_semi_cycle_second: False
#                use_spnorm: True                          	[default: False]
#                   verbose: False
#                 w_decay_G: 0.0001
#               weights_dir: ./checkpoints/pretrain_weights_imgdepht/
# ----------------- End -------------------
# wandb: W&B API key is configured (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.21
# wandb: Syncing run intnet_unflow_bigL_no_idtA_syn_holes
# wandb: ⭐️ View project at https://wandb.ai/blaabl/un_depth
# wandb: 🚀 View run at https://wandb.ai/blaabl/un_depth/runs/3q1rhbiz
# wandb: Run data is saved locally in /workspace/code/my_cyclegan/wandb/run-20210306_142658-3q1rhbiz
# wandb: Run `wandb offline` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 13744
# initialize network with xavier
# initialize network with xavier
# initialize network with xavier
# initialize network with xavier
# initialize network with xavier
# initialize network with xavier
# model [UnFlowGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.620 M
# [Network netG_B] Total number of parameters : 11.620 M
# [Network netD_A_depth] Total number of parameters : 2.762 M
# [Network netD_B_depth] Total number of parameters : 2.762 M
# [Network netD_A_normal] Total number of parameters : 2.764 M
# [Network netD_B_normal] Total number of parameters : 2.764 M
# -----------------------------------------------
# 240 img procesed out of 13744, taken 2.02 sec per 1 batch
# 480 img procesed out of 13744, taken 2.01 sec per 1 batch
# 720 img procesed out of 13744, taken 2.16 sec per 1 batch
# 960 img procesed out of 13744, taken 2.03 sec per 1 batch
# 1200 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1440 img procesed out of 13744, taken 2.09 sec per 1 batch
# 1680 img procesed out of 13744, taken 2.11 sec per 1 batch
# 1920 img procesed out of 13744, taken 2.12 sec per 1 batch
# 2160 img procesed out of 13744, taken 2.08 sec per 1 batch
# 2400 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2640 img procesed out of 13744, taken 2.08 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 2880 img procesed out of 13744, taken 2.07 sec per 1 batch
# 3120 img procesed out of 13744, taken 2.08 sec per 1 batch
# 3360 img procesed out of 13744, taken 2.13 sec per 1 batch
# All values are same
# Try new img
# 3600 img procesed out of 13744, taken 2.00 sec per 1 batch
# 3840 img procesed out of 13744, taken 1.97 sec per 1 batch
# All values are same
# Try new img
# 4080 img procesed out of 13744, taken 2.02 sec per 1 batch
# 4320 img procesed out of 13744, taken 2.01 sec per 1 batch
# 4560 img procesed out of 13744, taken 1.99 sec per 1 batch
# 4800 img procesed out of 13744, taken 2.15 sec per 1 batch
# 5040 img procesed out of 13744, taken 2.04 sec per 1 batch
# 5280 img procesed out of 13744, taken 2.07 sec per 1 batch
# 5520 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 5760 img procesed out of 13744, taken 2.11 sec per 1 batch
# 6000 img procesed out of 13744, taken 2.28 sec per 1 batch
# 6240 img procesed out of 13744, taken 2.13 sec per 1 batch
# 6480 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 6720 img procesed out of 13744, taken 2.02 sec per 1 batch
# 6960 img procesed out of 13744, taken 2.04 sec per 1 batch
# 7200 img procesed out of 13744, taken 2.03 sec per 1 batch
# 7440 img procesed out of 13744, taken 2.02 sec per 1 batch
# 7680 img procesed out of 13744, taken 2.03 sec per 1 batch
# 7920 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 8160 img procesed out of 13744, taken 1.98 sec per 1 batch
# 8400 img procesed out of 13744, taken 2.06 sec per 1 batch
# 8640 img procesed out of 13744, taken 2.07 sec per 1 batch
# 8880 img procesed out of 13744, taken 2.01 sec per 1 batch
# 9120 img procesed out of 13744, taken 2.04 sec per 1 batch
# 9360 img procesed out of 13744, taken 2.01 sec per 1 batch
# 9600 img procesed out of 13744, taken 2.03 sec per 1 batch
# 9840 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10080 img procesed out of 13744, taken 2.12 sec per 1 batch
# 10320 img procesed out of 13744, taken 2.04 sec per 1 batch
# 10560 img procesed out of 13744, taken 2.02 sec per 1 batch
# 10800 img procesed out of 13744, taken 2.02 sec per 1 batch
# 11040 img procesed out of 13744, taken 2.04 sec per 1 batch
# 11280 img procesed out of 13744, taken 2.05 sec per 1 batch
# 11520 img procesed out of 13744, taken 2.04 sec per 1 batch
# 11760 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 12000 img procesed out of 13744, taken 2.30 sec per 1 batch
# 12240 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 12480 img procesed out of 13744, taken 2.00 sec per 1 batch
# 12720 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 12960 img procesed out of 13744, taken 2.04 sec per 1 batch
# 13200 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 13440 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 13680 img procesed out of 13744, taken 2.03 sec per 1 batch
# End of epoch 1 / 300 	 Time Taken: 4950.05 sec
# learning rate = 0.0002000
# 174 img procesed out of 13744, taken 2.04 sec per 1 batch
# 414 img procesed out of 13744, taken 2.06 sec per 1 batch
# 654 img procesed out of 13744, taken 2.02 sec per 1 batch
# 894 img procesed out of 13744, taken 1.99 sec per 1 batch
# 1134 img procesed out of 13744, taken 2.01 sec per 1 batch
# 1374 img procesed out of 13744, taken 2.03 sec per 1 batch
# 1614 img procesed out of 13744, taken 2.01 sec per 1 batch
# 1854 img procesed out of 13744, taken 2.15 sec per 1 batch
# 2094 img procesed out of 13744, taken 2.11 sec per 1 batch
# 2334 img procesed out of 13744, taken 2.04 sec per 1 batch
# 2574 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2814 img procesed out of 13744, taken 2.01 sec per 1 batch
# 3054 img procesed out of 13744, taken 2.05 sec per 1 batch
# 3294 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 3534 img procesed out of 13744, taken 1.99 sec per 1 batch
# 3774 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 4014 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 4254 img procesed out of 13744, taken 2.38 sec per 1 batch
# 4494 img procesed out of 13744, taken 2.01 sec per 1 batch
# 4734 img procesed out of 13744, taken 2.07 sec per 1 batch
# 4974 img procesed out of 13744, taken 2.03 sec per 1 batch
# 5214 img procesed out of 13744, taken 2.04 sec per 1 batch
# 5454 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5694 img procesed out of 13744, taken 2.05 sec per 1 batch
# 5934 img procesed out of 13744, taken 2.01 sec per 1 batch
# 6174 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 6414 img procesed out of 13744, taken 2.06 sec per 1 batch
# 6654 img procesed out of 13744, taken 2.01 sec per 1 batch
# 6894 img procesed out of 13744, taken 2.12 sec per 1 batch
# 7134 img procesed out of 13744, taken 2.05 sec per 1 batch
# 7374 img procesed out of 13744, taken 2.05 sec per 1 batch
# 7614 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 7854 img procesed out of 13744, taken 2.07 sec per 1 batch
# 8094 img procesed out of 13744, taken 2.01 sec per 1 batch
# 8334 img procesed out of 13744, taken 2.14 sec per 1 batch
# 8574 img procesed out of 13744, taken 2.03 sec per 1 batch
# 8814 img procesed out of 13744, taken 2.03 sec per 1 batch
# All values are same
# Try new img
# 9054 img procesed out of 13744, taken 1.98 sec per 1 batch
# 9294 img procesed out of 13744, taken 2.07 sec per 1 batch
# All values are same
# Try new img
# 9534 img procesed out of 13744, taken 2.05 sec per 1 batch
# 9774 img procesed out of 13744, taken 2.09 sec per 1 batch
# 10014 img procesed out of 13744, taken 2.01 sec per 1 batch
# 10254 img procesed out of 13744, taken 2.32 sec per 1 batch
# 10494 img procesed out of 13744, taken 2.02 sec per 1 batch
# 10734 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10974 img procesed out of 13744, taken 2.08 sec per 1 batch
# 11214 img procesed out of 13744, taken 2.00 sec per 1 batch
# 11454 img procesed out of 13744, taken 2.06 sec per 1 batch
# 11694 img procesed out of 13744, taken 2.10 sec per 1 batch
# 11934 img procesed out of 13744, taken 2.09 sec per 1 batch
# 12174 img procesed out of 13744, taken 1.99 sec per 1 batch
# 12414 img procesed out of 13744, taken 2.10 sec per 1 batch
# 12654 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 12894 img procesed out of 13744, taken 2.11 sec per 1 batch
# 13134 img procesed out of 13744, taken 2.01 sec per 1 batch
# 13374 img procesed out of 13744, taken 2.11 sec per 1 batch
# All values are same
# Try new img
# 13614 img procesed out of 13744, taken 2.01 sec per 1 batch
# End of epoch 2 / 300 	 Time Taken: 4939.92 sec
# learning rate = 0.0002000
# 108 img procesed out of 13744, taken 2.06 sec per 1 batch
# 348 img procesed out of 13744, taken 2.09 sec per 1 batch
# 588 img procesed out of 13744, taken 1.99 sec per 1 batch
# 828 img procesed out of 13744, taken 2.01 sec per 1 batch
# 1068 img procesed out of 13744, taken 2.10 sec per 1 batch
# 1308 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 1548 img procesed out of 13744, taken 2.12 sec per 1 batch
# 1788 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 2028 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2268 img procesed out of 13744, taken 2.01 sec per 1 batch
# 2508 img procesed out of 13744, taken 2.35 sec per 1 batch
# 2748 img procesed out of 13744, taken 2.12 sec per 1 batch
# 2988 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 3228 img procesed out of 13744, taken 2.11 sec per 1 batch
# 3468 img procesed out of 13744, taken 2.13 sec per 1 batch
# 3708 img procesed out of 13744, taken 2.02 sec per 1 batch
# 3948 img procesed out of 13744, taken 2.11 sec per 1 batch
# 4188 img procesed out of 13744, taken 2.09 sec per 1 batch
# 4428 img procesed out of 13744, taken 2.00 sec per 1 batch
# 4668 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 4908 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5148 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5388 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 5628 img procesed out of 13744, taken 2.07 sec per 1 batch
# 5868 img procesed out of 13744, taken 2.04 sec per 1 batch
# 6108 img procesed out of 13744, taken 2.09 sec per 1 batch
# 6348 img procesed out of 13744, taken 1.99 sec per 1 batch
# 6588 img procesed out of 13744, taken 2.03 sec per 1 batch
# 6828 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 7068 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 7308 img procesed out of 13744, taken 2.04 sec per 1 batch
# 7548 img procesed out of 13744, taken 2.01 sec per 1 batch
# 7788 img procesed out of 13744, taken 1.98 sec per 1 batch
# All values are same
# Try new img
# 8028 img procesed out of 13744, taken 1.99 sec per 1 batch
# 8268 img procesed out of 13744, taken 2.01 sec per 1 batch
# 8508 img procesed out of 13744, taken 2.33 sec per 1 batch
# All values are same
# Try new img
# 8748 img procesed out of 13744, taken 2.03 sec per 1 batch
# 8988 img procesed out of 13744, taken 2.02 sec per 1 batch
# 9228 img procesed out of 13744, taken 2.10 sec per 1 batch
# All values are same
# Try new img
# 9468 img procesed out of 13744, taken 2.03 sec per 1 batch
# 9708 img procesed out of 13744, taken 2.02 sec per 1 batch
# 9948 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10188 img procesed out of 13744, taken 1.98 sec per 1 batch
# 10428 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10668 img procesed out of 13744, taken 2.01 sec per 1 batch
# 10908 img procesed out of 13744, taken 2.02 sec per 1 batch
# 11148 img procesed out of 13744, taken 2.00 sec per 1 batch
# 11388 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 11628 img procesed out of 13744, taken 2.02 sec per 1 batch
# 11868 img procesed out of 13744, taken 2.05 sec per 1 batch
# 12108 img procesed out of 13744, taken 2.04 sec per 1 batch
# 12348 img procesed out of 13744, taken 2.00 sec per 1 batch
# 12588 img procesed out of 13744, taken 1.98 sec per 1 batch
# 12828 img procesed out of 13744, taken 2.02 sec per 1 batch
# 13068 img procesed out of 13744, taken 2.00 sec per 1 batch
# 13308 img procesed out of 13744, taken 2.07 sec per 1 batch
# 13548 img procesed out of 13744, taken 2.10 sec per 1 batch
# End of epoch 3 / 300 	 Time Taken: 4939.23 sec
# learning rate = 0.0002000
# 42 img procesed out of 13744, taken 2.03 sec per 1 batch
# 282 img procesed out of 13744, taken 2.02 sec per 1 batch
# 522 img procesed out of 13744, taken 1.99 sec per 1 batch
# 762 img procesed out of 13744, taken 2.43 sec per 1 batch
# 1002 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1242 img procesed out of 13744, taken 2.07 sec per 1 batch
# 1482 img procesed out of 13744, taken 2.00 sec per 1 batch
# 1722 img procesed out of 13744, taken 2.13 sec per 1 batch
# All values are same
# Try new img
# 1962 img procesed out of 13744, taken 2.05 sec per 1 batch
# 2202 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2442 img procesed out of 13744, taken 2.11 sec per 1 batch
# 2682 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 2922 img procesed out of 13744, taken 2.02 sec per 1 batch
# 3162 img procesed out of 13744, taken 2.05 sec per 1 batch
# 3402 img procesed out of 13744, taken 2.18 sec per 1 batch
# All values are same
# Try new img
# 3642 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 3882 img procesed out of 13744, taken 2.03 sec per 1 batch
# 4122 img procesed out of 13744, taken 2.09 sec per 1 batch
# 4362 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 4602 img procesed out of 13744, taken 2.14 sec per 1 batch
# 4842 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 5082 img procesed out of 13744, taken 1.99 sec per 1 batch
# 5322 img procesed out of 13744, taken 2.14 sec per 1 batch
# 5562 img procesed out of 13744, taken 2.06 sec per 1 batch
# 5802 img procesed out of 13744, taken 2.02 sec per 1 batch
# 6042 img procesed out of 13744, taken 2.04 sec per 1 batch
# 6282 img procesed out of 13744, taken 1.99 sec per 1 batch
# 6522 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6762 img procesed out of 13744, taken 2.45 sec per 1 batch
# 7002 img procesed out of 13744, taken 2.03 sec per 1 batch
# 7242 img procesed out of 13744, taken 1.98 sec per 1 batch
# 7482 img procesed out of 13744, taken 2.00 sec per 1 batch
# 7722 img procesed out of 13744, taken 1.99 sec per 1 batch
# 7962 img procesed out of 13744, taken 2.10 sec per 1 batch
# 8202 img procesed out of 13744, taken 2.06 sec per 1 batch
# 8442 img procesed out of 13744, taken 2.12 sec per 1 batch
# 8682 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 8922 img procesed out of 13744, taken 2.08 sec per 1 batch
# 9162 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 9402 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 9642 img procesed out of 13744, taken 1.99 sec per 1 batch
# 9882 img procesed out of 13744, taken 2.03 sec per 1 batch
# All values are same
# Try new img
# 10122 img procesed out of 13744, taken 2.12 sec per 1 batch
# 10362 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 10602 img procesed out of 13744, taken 2.11 sec per 1 batch
# 10842 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 11082 img procesed out of 13744, taken 2.12 sec per 1 batch
# 11322 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 11562 img procesed out of 13744, taken 2.11 sec per 1 batch
# 11802 img procesed out of 13744, taken 2.02 sec per 1 batch
# 12042 img procesed out of 13744, taken 1.99 sec per 1 batch
# 12282 img procesed out of 13744, taken 2.01 sec per 1 batch
# 12522 img procesed out of 13744, taken 1.99 sec per 1 batch
# 12762 img procesed out of 13744, taken 2.29 sec per 1 batch
# 13002 img procesed out of 13744, taken 2.01 sec per 1 batch
# 13242 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 13482 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 13722 img procesed out of 13744, taken 2.00 sec per 1 batch
# End of epoch 4 / 300 	 Time Taken: 4930.20 sec
# learning rate = 0.0002000
# 216 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 456 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 696 img procesed out of 13744, taken 2.00 sec per 1 batch
# 936 img procesed out of 13744, taken 1.99 sec per 1 batch
# 1176 img procesed out of 13744, taken 1.99 sec per 1 batch
# 1416 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1656 img procesed out of 13744, taken 2.00 sec per 1 batch
# 1896 img procesed out of 13744, taken 2.03 sec per 1 batch
# 2136 img procesed out of 13744, taken 2.12 sec per 1 batch
# 2376 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 2616 img procesed out of 13744, taken 2.12 sec per 1 batch
# All values are same
# Try new img
# 2856 img procesed out of 13744, taken 2.00 sec per 1 batch
# 3096 img procesed out of 13744, taken 2.13 sec per 1 batch
# 3336 img procesed out of 13744, taken 1.96 sec per 1 batch
# 3576 img procesed out of 13744, taken 2.04 sec per 1 batch
# 3816 img procesed out of 13744, taken 2.10 sec per 1 batch
# All values are same
# Try new img
# 4056 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 4296 img procesed out of 13744, taken 2.02 sec per 1 batch
# 4536 img procesed out of 13744, taken 2.07 sec per 1 batch
# 4776 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 5016 img procesed out of 13744, taken 2.47 sec per 1 batch
# 5256 img procesed out of 13744, taken 2.12 sec per 1 batch
# 5496 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5736 img procesed out of 13744, taken 2.07 sec per 1 batch
# 5976 img procesed out of 13744, taken 2.10 sec per 1 batch
# 6216 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6456 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6696 img procesed out of 13744, taken 2.03 sec per 1 batch
# 6936 img procesed out of 13744, taken 2.11 sec per 1 batch
# 7176 img procesed out of 13744, taken 2.08 sec per 1 batch
# 7416 img procesed out of 13744, taken 2.03 sec per 1 batch
# 7656 img procesed out of 13744, taken 1.98 sec per 1 batch
# 7896 img procesed out of 13744, taken 2.02 sec per 1 batch
# 8136 img procesed out of 13744, taken 2.07 sec per 1 batch
# All values are same
# Try new img
# 8376 img procesed out of 13744, taken 1.98 sec per 1 batch
# 8616 img procesed out of 13744, taken 2.11 sec per 1 batch
# 8856 img procesed out of 13744, taken 2.02 sec per 1 batch
# 9096 img procesed out of 13744, taken 1.98 sec per 1 batch
# All values are same
# Try new img
# 9336 img procesed out of 13744, taken 2.03 sec per 1 batch
# 9576 img procesed out of 13744, taken 2.08 sec per 1 batch
# 9816 img procesed out of 13744, taken 1.99 sec per 1 batch
# 10056 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10296 img procesed out of 13744, taken 1.99 sec per 1 batch
# 10536 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 10776 img procesed out of 13744, taken 2.05 sec per 1 batch
# 11016 img procesed out of 13744, taken 2.46 sec per 1 batch
# 11256 img procesed out of 13744, taken 2.06 sec per 1 batch
# 11496 img procesed out of 13744, taken 1.99 sec per 1 batch
# 11736 img procesed out of 13744, taken 2.12 sec per 1 batch
# 11976 img procesed out of 13744, taken 2.02 sec per 1 batch
# 12216 img procesed out of 13744, taken 1.98 sec per 1 batch
# 12456 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 12696 img procesed out of 13744, taken 1.97 sec per 1 batch
# 12936 img procesed out of 13744, taken 2.03 sec per 1 batch
# All values are same
# Try new img
# 13176 img procesed out of 13744, taken 1.98 sec per 1 batch
# 13416 img procesed out of 13744, taken 2.13 sec per 1 batch
# 13656 img procesed out of 13744, taken 2.01 sec per 1 batch
# saving the model at the end of epoch 5, iters 11455
# End of epoch 5 / 300 	 Time Taken: 4926.05 sec
# learning rate = 0.0002000
# 150 img procesed out of 13744, taken 2.14 sec per 1 batch
# 390 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 630 img procesed out of 13744, taken 1.99 sec per 1 batch
# 870 img procesed out of 13744, taken 2.09 sec per 1 batch
# 1110 img procesed out of 13744, taken 2.14 sec per 1 batch
# 1350 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 1590 img procesed out of 13744, taken 2.04 sec per 1 batch
# 1830 img procesed out of 13744, taken 2.07 sec per 1 batch
# 2070 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2310 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2550 img procesed out of 13744, taken 2.05 sec per 1 batch
# 2790 img procesed out of 13744, taken 2.15 sec per 1 batch
# 3030 img procesed out of 13744, taken 2.06 sec per 1 batch
# 3270 img procesed out of 13744, taken 2.30 sec per 1 batch
# All values are same
# Try new img
# 3510 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 3750 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 3990 img procesed out of 13744, taken 2.02 sec per 1 batch
# 4230 img procesed out of 13744, taken 2.04 sec per 1 batch
# 4470 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 4710 img procesed out of 13744, taken 2.01 sec per 1 batch
# 4950 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 5190 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5430 img procesed out of 13744, taken 2.04 sec per 1 batch
# 5670 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 5910 img procesed out of 13744, taken 2.14 sec per 1 batch
# All values are same
# Try new img
# 6150 img procesed out of 13744, taken 1.99 sec per 1 batch
# 6390 img procesed out of 13744, taken 2.02 sec per 1 batch
# 6630 img procesed out of 13744, taken 2.11 sec per 1 batch
# 6870 img procesed out of 13744, taken 2.01 sec per 1 batch
# 7110 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 7350 img procesed out of 13744, taken 2.00 sec per 1 batch
# 7590 img procesed out of 13744, taken 2.04 sec per 1 batch
# 7830 img procesed out of 13744, taken 2.00 sec per 1 batch
# 8070 img procesed out of 13744, taken 2.03 sec per 1 batch
# 8310 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 8550 img procesed out of 13744, taken 2.07 sec per 1 batch
# 8790 img procesed out of 13744, taken 2.01 sec per 1 batch
# 9030 img procesed out of 13744, taken 1.97 sec per 1 batch
# 9270 img procesed out of 13744, taken 2.32 sec per 1 batch
# 9510 img procesed out of 13744, taken 2.03 sec per 1 batch
# 9750 img procesed out of 13744, taken 2.05 sec per 1 batch
# 9990 img procesed out of 13744, taken 2.11 sec per 1 batch
# 10230 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 10470 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10710 img procesed out of 13744, taken 2.13 sec per 1 batch
# All values are same
# Try new img
# 10950 img procesed out of 13744, taken 2.11 sec per 1 batch
# 11190 img procesed out of 13744, taken 2.07 sec per 1 batch
# 11430 img procesed out of 13744, taken 2.03 sec per 1 batch
# 11670 img procesed out of 13744, taken 2.07 sec per 1 batch
# 11910 img procesed out of 13744, taken 2.11 sec per 1 batch
# 12150 img procesed out of 13744, taken 2.09 sec per 1 batch
# 12390 img procesed out of 13744, taken 2.14 sec per 1 batch
# All values are same
# Try new img
# 12630 img procesed out of 13744, taken 2.06 sec per 1 batch
# 12870 img procesed out of 13744, taken 2.09 sec per 1 batch
# 13110 img procesed out of 13744, taken 2.05 sec per 1 batch
# 13350 img procesed out of 13744, taken 2.09 sec per 1 batch
# 13590 img procesed out of 13744, taken 1.97 sec per 1 batch
# End of epoch 6 / 300 	 Time Taken: 4920.93 sec
# learning rate = 0.0002000
# 84 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 324 img procesed out of 13744, taken 2.10 sec per 1 batch
# All values are same
# Try new img
# 564 img procesed out of 13744, taken 2.03 sec per 1 batch
# 804 img procesed out of 13744, taken 1.98 sec per 1 batch
# 1044 img procesed out of 13744, taken 1.98 sec per 1 batch
# 1284 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1524 img procesed out of 13744, taken 2.33 sec per 1 batch
# All values are same
# Try new img
# 1764 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2004 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2244 img procesed out of 13744, taken 1.99 sec per 1 batch
# 2484 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2724 img procesed out of 13744, taken 2.08 sec per 1 batch
# 2964 img procesed out of 13744, taken 2.01 sec per 1 batch
# 3204 img procesed out of 13744, taken 2.00 sec per 1 batch
# 3444 img procesed out of 13744, taken 2.04 sec per 1 batch
# 3684 img procesed out of 13744, taken 2.01 sec per 1 batch
# 3924 img procesed out of 13744, taken 2.08 sec per 1 batch
# 4164 img procesed out of 13744, taken 2.03 sec per 1 batch
# All values are same
# Try new img
# 4404 img procesed out of 13744, taken 2.03 sec per 1 batch
# 4644 img procesed out of 13744, taken 2.13 sec per 1 batch
# 4884 img procesed out of 13744, taken 1.96 sec per 1 batch
# 5124 img procesed out of 13744, taken 2.13 sec per 1 batch
# 5364 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5604 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5844 img procesed out of 13744, taken 2.07 sec per 1 batch
# All values are same
# Try new img
# 6084 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6324 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6564 img procesed out of 13744, taken 2.08 sec per 1 batch
# 6804 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 7044 img procesed out of 13744, taken 2.02 sec per 1 batch
# 7284 img procesed out of 13744, taken 1.99 sec per 1 batch
# 7524 img procesed out of 13744, taken 2.44 sec per 1 batch
# 7764 img procesed out of 13744, taken 2.10 sec per 1 batch
# 8004 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 8244 img procesed out of 13744, taken 2.08 sec per 1 batch
# All values are same
# Try new img
# 8484 img procesed out of 13744, taken 1.98 sec per 1 batch
# All values are same
# Try new img
# 8724 img procesed out of 13744, taken 2.03 sec per 1 batch
# 8964 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 9204 img procesed out of 13744, taken 1.98 sec per 1 batch
# 9444 img procesed out of 13744, taken 2.07 sec per 1 batch
# 9684 img procesed out of 13744, taken 2.04 sec per 1 batch
# 9924 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10164 img procesed out of 13744, taken 1.98 sec per 1 batch
# 10404 img procesed out of 13744, taken 1.98 sec per 1 batch
# All values are same
# Try new img
# 10644 img procesed out of 13744, taken 2.06 sec per 1 batch
# 10884 img procesed out of 13744, taken 1.98 sec per 1 batch
# 11124 img procesed out of 13744, taken 2.10 sec per 1 batch
# 11364 img procesed out of 13744, taken 2.06 sec per 1 batch
# 11604 img procesed out of 13744, taken 2.00 sec per 1 batch
# 11844 img procesed out of 13744, taken 2.06 sec per 1 batch
# 12084 img procesed out of 13744, taken 2.02 sec per 1 batch
# 12324 img procesed out of 13744, taken 2.04 sec per 1 batch
# 12564 img procesed out of 13744, taken 2.12 sec per 1 batch
# 12804 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 13044 img procesed out of 13744, taken 1.99 sec per 1 batch
# 13284 img procesed out of 13744, taken 2.04 sec per 1 batch
# 13524 img procesed out of 13744, taken 2.33 sec per 1 batch
# End of epoch 7 / 300 	 Time Taken: 4909.84 sec
# learning rate = 0.0002000
# 18 img procesed out of 13744, taken 2.09 sec per 1 batch
# 258 img procesed out of 13744, taken 2.02 sec per 1 batch
# 498 img procesed out of 13744, taken 2.01 sec per 1 batch
# 738 img procesed out of 13744, taken 2.06 sec per 1 batch
# 978 img procesed out of 13744, taken 1.97 sec per 1 batch
# 1218 img procesed out of 13744, taken 2.07 sec per 1 batch
# All values are same
# Try new img
# 1458 img procesed out of 13744, taken 2.10 sec per 1 batch
# 1698 img procesed out of 13744, taken 2.03 sec per 1 batch
# All values are same
# Try new img
# 1938 img procesed out of 13744, taken 2.10 sec per 1 batch
# 2178 img procesed out of 13744, taken 2.14 sec per 1 batch
# 2418 img procesed out of 13744, taken 2.10 sec per 1 batch
# 2658 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2898 img procesed out of 13744, taken 1.99 sec per 1 batch
# 3138 img procesed out of 13744, taken 2.13 sec per 1 batch
# All values are same
# Try new img
# 3378 img procesed out of 13744, taken 2.06 sec per 1 batch
# 3618 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 3858 img procesed out of 13744, taken 2.05 sec per 1 batch
# 4098 img procesed out of 13744, taken 2.02 sec per 1 batch
# 4338 img procesed out of 13744, taken 2.04 sec per 1 batch
# 4578 img procesed out of 13744, taken 2.10 sec per 1 batch
# All values are same
# Try new img
# 4818 img procesed out of 13744, taken 1.97 sec per 1 batch
# 5058 img procesed out of 13744, taken 2.02 sec per 1 batch
# 5298 img procesed out of 13744, taken 2.04 sec per 1 batch
# 5538 img procesed out of 13744, taken 2.00 sec per 1 batch
# 5778 img procesed out of 13744, taken 2.38 sec per 1 batch
# 6018 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 6258 img procesed out of 13744, taken 2.10 sec per 1 batch
# 6498 img procesed out of 13744, taken 2.07 sec per 1 batch
# 6738 img procesed out of 13744, taken 2.06 sec per 1 batch
# 6978 img procesed out of 13744, taken 2.08 sec per 1 batch
# 7218 img procesed out of 13744, taken 2.12 sec per 1 batch
# 7458 img procesed out of 13744, taken 2.00 sec per 1 batch
# 7698 img procesed out of 13744, taken 2.05 sec per 1 batch
# 7938 img procesed out of 13744, taken 2.11 sec per 1 batch
# 8178 img procesed out of 13744, taken 2.00 sec per 1 batch
# 8418 img procesed out of 13744, taken 2.01 sec per 1 batch
# 8658 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 8898 img procesed out of 13744, taken 2.16 sec per 1 batch
# All values are same
# Try new img
# 9138 img procesed out of 13744, taken 1.97 sec per 1 batch
# All values are same
# Try new img
# 9378 img procesed out of 13744, taken 2.03 sec per 1 batch
# 9618 img procesed out of 13744, taken 1.99 sec per 1 batch
# 9858 img procesed out of 13744, taken 1.98 sec per 1 batch
# 10098 img procesed out of 13744, taken 2.00 sec per 1 batch
# 10338 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10578 img procesed out of 13744, taken 2.00 sec per 1 batch
# 10818 img procesed out of 13744, taken 1.99 sec per 1 batch
# 11058 img procesed out of 13744, taken 2.01 sec per 1 batch
# 11298 img procesed out of 13744, taken 2.01 sec per 1 batch
# 11538 img procesed out of 13744, taken 2.03 sec per 1 batch
# 11778 img procesed out of 13744, taken 2.34 sec per 1 batch
# 12018 img procesed out of 13744, taken 2.04 sec per 1 batch
# 12258 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 12498 img procesed out of 13744, taken 2.02 sec per 1 batch
# 12738 img procesed out of 13744, taken 2.03 sec per 1 batch
# 12978 img procesed out of 13744, taken 2.00 sec per 1 batch
# 13218 img procesed out of 13744, taken 2.03 sec per 1 batch
# 13458 img procesed out of 13744, taken 2.09 sec per 1 batch
# 13698 img procesed out of 13744, taken 2.03 sec per 1 batch
# End of epoch 8 / 300 	 Time Taken: 4911.44 sec
# learning rate = 0.0002000
# All values are same
# Try new img
# All values are same
# Try new img
# All values are same
# Try new img
# 192 img procesed out of 13744, taken 1.99 sec per 1 batch
# 432 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 672 img procesed out of 13744, taken 2.11 sec per 1 batch
# 912 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 1152 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 1392 img procesed out of 13744, taken 2.03 sec per 1 batch
# 1632 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 1872 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2112 img procesed out of 13744, taken 2.05 sec per 1 batch
# 2352 img procesed out of 13744, taken 2.07 sec per 1 batch
# 2592 img procesed out of 13744, taken 2.15 sec per 1 batch
# All values are same
# Try new img
# 2832 img procesed out of 13744, taken 2.01 sec per 1 batch
# 3072 img procesed out of 13744, taken 2.02 sec per 1 batch
# 3312 img procesed out of 13744, taken 1.99 sec per 1 batch
# 3552 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 3792 img procesed out of 13744, taken 2.00 sec per 1 batch
# 4032 img procesed out of 13744, taken 2.29 sec per 1 batch
# 4272 img procesed out of 13744, taken 2.05 sec per 1 batch
# 4512 img procesed out of 13744, taken 2.10 sec per 1 batch
# 4752 img procesed out of 13744, taken 2.13 sec per 1 batch
# 4992 img procesed out of 13744, taken 2.11 sec per 1 batch
# 5232 img procesed out of 13744, taken 2.01 sec per 1 batch
# 5472 img procesed out of 13744, taken 2.12 sec per 1 batch
# 5712 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 5952 img procesed out of 13744, taken 2.07 sec per 1 batch
# 6192 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 6432 img procesed out of 13744, taken 2.11 sec per 1 batch
# 6672 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6912 img procesed out of 13744, taken 2.03 sec per 1 batch
# 7152 img procesed out of 13744, taken 2.12 sec per 1 batch
# 7392 img procesed out of 13744, taken 2.07 sec per 1 batch
# All values are same
# Try new img
# 7632 img procesed out of 13744, taken 2.05 sec per 1 batch
# 7872 img procesed out of 13744, taken 2.03 sec per 1 batch
# 8112 img procesed out of 13744, taken 2.12 sec per 1 batch
# 8352 img procesed out of 13744, taken 2.01 sec per 1 batch
# 8592 img procesed out of 13744, taken 1.98 sec per 1 batch
# 8832 img procesed out of 13744, taken 2.12 sec per 1 batch
# 9072 img procesed out of 13744, taken 1.96 sec per 1 batch
# 9312 img procesed out of 13744, taken 2.02 sec per 1 batch
# 9552 img procesed out of 13744, taken 2.10 sec per 1 batch
# 9792 img procesed out of 13744, taken 2.09 sec per 1 batch
# 10032 img procesed out of 13744, taken 2.30 sec per 1 batch
# 10272 img procesed out of 13744, taken 2.14 sec per 1 batch
# 10512 img procesed out of 13744, taken 2.01 sec per 1 batch
# 10752 img procesed out of 13744, taken 2.00 sec per 1 batch
# 10992 img procesed out of 13744, taken 2.06 sec per 1 batch
# 11232 img procesed out of 13744, taken 2.09 sec per 1 batch
# 11472 img procesed out of 13744, taken 2.03 sec per 1 batch
# 11712 img procesed out of 13744, taken 2.16 sec per 1 batch
# 11952 img procesed out of 13744, taken 1.98 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 12192 img procesed out of 13744, taken 2.13 sec per 1 batch
# 12432 img procesed out of 13744, taken 2.08 sec per 1 batch
# 12672 img procesed out of 13744, taken 2.13 sec per 1 batch
# 12912 img procesed out of 13744, taken 2.09 sec per 1 batch
# 13152 img procesed out of 13744, taken 2.00 sec per 1 batch
# 13392 img procesed out of 13744, taken 1.95 sec per 1 batch
# 13632 img procesed out of 13744, taken 2.12 sec per 1 batch
# End of epoch 9 / 300 	 Time Taken: 4914.28 sec
# learning rate = 0.0002000
# 126 img procesed out of 13744, taken 2.03 sec per 1 batch
# 366 img procesed out of 13744, taken 2.03 sec per 1 batch
# 606 img procesed out of 13744, taken 2.10 sec per 1 batch
# All values are same
# Try new img
# 846 img procesed out of 13744, taken 1.99 sec per 1 batch
# 1086 img procesed out of 13744, taken 2.17 sec per 1 batch
# All values are same
# Try new img
# 1326 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1566 img procesed out of 13744, taken 2.01 sec per 1 batch
# 1806 img procesed out of 13744, taken 1.99 sec per 1 batch
# 2046 img procesed out of 13744, taken 1.98 sec per 1 batch
# 2286 img procesed out of 13744, taken 2.39 sec per 1 batch
# All values are same
# Try new img
# 2526 img procesed out of 13744, taken 2.10 sec per 1 batch
# 2766 img procesed out of 13744, taken 2.04 sec per 1 batch
# 3006 img procesed out of 13744, taken 2.02 sec per 1 batch
# 3246 img procesed out of 13744, taken 2.00 sec per 1 batch
# 3486 img procesed out of 13744, taken 2.06 sec per 1 batch
# 3726 img procesed out of 13744, taken 1.98 sec per 1 batch
# 3966 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 4206 img procesed out of 13744, taken 2.03 sec per 1 batch
# 4446 img procesed out of 13744, taken 2.03 sec per 1 batch
# 4686 img procesed out of 13744, taken 2.10 sec per 1 batch
# 4926 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 5166 img procesed out of 13744, taken 2.05 sec per 1 batch
# 5406 img procesed out of 13744, taken 2.02 sec per 1 batch
# 5646 img procesed out of 13744, taken 1.98 sec per 1 batch
# 5886 img procesed out of 13744, taken 2.05 sec per 1 batch
# 6126 img procesed out of 13744, taken 2.10 sec per 1 batch
# 6366 img procesed out of 13744, taken 2.06 sec per 1 batch
# 6606 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6846 img procesed out of 13744, taken 1.98 sec per 1 batch
# 7086 img procesed out of 13744, taken 1.99 sec per 1 batch
# 7326 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 7566 img procesed out of 13744, taken 2.07 sec per 1 batch
# 7806 img procesed out of 13744, taken 2.07 sec per 1 batch
# 8046 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 8286 img procesed out of 13744, taken 2.38 sec per 1 batch
# 8526 img procesed out of 13744, taken 1.98 sec per 1 batch
# 8766 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 9006 img procesed out of 13744, taken 1.97 sec per 1 batch
# 9246 img procesed out of 13744, taken 2.04 sec per 1 batch
# 9486 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 9726 img procesed out of 13744, taken 1.98 sec per 1 batch
# All values are same
# Try new img
# 9966 img procesed out of 13744, taken 2.11 sec per 1 batch
# 10206 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 10446 img procesed out of 13744, taken 2.09 sec per 1 batch
# 10686 img procesed out of 13744, taken 2.05 sec per 1 batch
# 10926 img procesed out of 13744, taken 2.07 sec per 1 batch
# 11166 img procesed out of 13744, taken 2.08 sec per 1 batch
# 11406 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 11646 img procesed out of 13744, taken 2.06 sec per 1 batch
# 11886 img procesed out of 13744, taken 2.07 sec per 1 batch
# 12126 img procesed out of 13744, taken 2.06 sec per 1 batch
# 12366 img procesed out of 13744, taken 1.98 sec per 1 batch
# 12606 img procesed out of 13744, taken 1.98 sec per 1 batch
# All values are same
# Try new img
# 12846 img procesed out of 13744, taken 2.00 sec per 1 batch
# 13086 img procesed out of 13744, taken 2.07 sec per 1 batch
# 13326 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 13566 img procesed out of 13744, taken 2.00 sec per 1 batch
# saving the model at the end of epoch 10, iters 22910
# End of epoch 10 / 300 	 Time Taken: 4911.32 sec
# learning rate = 0.0002000
# 60 img procesed out of 13744, taken 2.07 sec per 1 batch
# 300 img procesed out of 13744, taken 2.03 sec per 1 batch
# 540 img procesed out of 13744, taken 2.49 sec per 1 batch
# 780 img procesed out of 13744, taken 2.00 sec per 1 batch
# 1020 img procesed out of 13744, taken 1.98 sec per 1 batch
# 1260 img procesed out of 13744, taken 1.99 sec per 1 batch
# 1500 img procesed out of 13744, taken 2.01 sec per 1 batch
# 1740 img procesed out of 13744, taken 1.99 sec per 1 batch
# 1980 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2220 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2460 img procesed out of 13744, taken 2.05 sec per 1 batch
# 2700 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 2940 img procesed out of 13744, taken 2.04 sec per 1 batch
# 3180 img procesed out of 13744, taken 1.99 sec per 1 batch
# 3420 img procesed out of 13744, taken 2.01 sec per 1 batch
# 3660 img procesed out of 13744, taken 2.06 sec per 1 batch
# 3900 img procesed out of 13744, taken 2.01 sec per 1 batch
# 4140 img procesed out of 13744, taken 1.98 sec per 1 batch
# 4380 img procesed out of 13744, taken 2.06 sec per 1 batch
# 4620 img procesed out of 13744, taken 2.09 sec per 1 batch
# 4860 img procesed out of 13744, taken 2.04 sec per 1 batch
# 5100 img procesed out of 13744, taken 2.04 sec per 1 batch
# 5340 img procesed out of 13744, taken 2.00 sec per 1 batch
# 5580 img procesed out of 13744, taken 2.05 sec per 1 batch
# 5820 img procesed out of 13744, taken 2.01 sec per 1 batch
# 6060 img procesed out of 13744, taken 2.04 sec per 1 batch
# 6300 img procesed out of 13744, taken 2.01 sec per 1 batch
# 6540 img procesed out of 13744, taken 2.37 sec per 1 batch
# 6780 img procesed out of 13744, taken 2.02 sec per 1 batch
# 7020 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 7260 img procesed out of 13744, taken 2.04 sec per 1 batch
# 7500 img procesed out of 13744, taken 2.13 sec per 1 batch
# All values are same
# Try new img
# 7740 img procesed out of 13744, taken 1.99 sec per 1 batch
# ...
# 2346 img procesed out of 13744, taken 2.01 sec per 1 batch
# 2586 img procesed out of 13744, taken 1.99 sec per 1 batch
# 2826 img procesed out of 13744, taken 2.37 sec per 1 batch
# 3066 img procesed out of 13744, taken 2.07 sec per 1 batch
# 3306 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 3546 img procesed out of 13744, taken 2.07 sec per 1 batch
# 3786 img procesed out of 13744, taken 2.03 sec per 1 batch
# 4026 img procesed out of 13744, taken 2.11 sec per 1 batch
# 4266 img procesed out of 13744, taken 2.02 sec per 1 batch
# 4506 img procesed out of 13744, taken 2.00 sec per 1 batch
# 4746 img procesed out of 13744, taken 2.04 sec per 1 batch
# 4986 img procesed out of 13744, taken 2.14 sec per 1 batch
# 5226 img procesed out of 13744, taken 2.00 sec per 1 batch
# 5466 img procesed out of 13744, taken 2.02 sec per 1 batch
# 5706 img procesed out of 13744, taken 2.08 sec per 1 batch
# 5946 img procesed out of 13744, taken 2.14 sec per 1 batch
# 6186 img procesed out of 13744, taken 2.09 sec per 1 batch
# All values are same
# Try new img
# 6426 img procesed out of 13744, taken 1.99 sec per 1 batch
# 6666 img procesed out of 13744, taken 2.03 sec per 1 batch
# All values are same
# Try new img
# 6906 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 7146 img procesed out of 13744, taken 2.06 sec per 1 batch
# 7386 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 7626 img procesed out of 13744, taken 2.04 sec per 1 batch
# 7866 img procesed out of 13744, taken 2.03 sec per 1 batch
# 8106 img procesed out of 13744, taken 2.09 sec per 1 batch
# 8346 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 8586 img procesed out of 13744, taken 2.08 sec per 1 batch
# All values are same
# Try new img
# 8826 img procesed out of 13744, taken 2.36 sec per 1 batch
# 9066 img procesed out of 13744, taken 1.99 sec per 1 batch
# 9306 img procesed out of 13744, taken 2.08 sec per 1 batch
# 9546 img procesed out of 13744, taken 2.05 sec per 1 batch
# 9786 img procesed out of 13744, taken 1.99 sec per 1 batch
# 10026 img procesed out of 13744, taken 2.16 sec per 1 batch
# 10266 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 10506 img procesed out of 13744, taken 2.01 sec per 1 batch
# 10746 img procesed out of 13744, taken 2.05 sec per 1 batch
# 10986 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 11226 img procesed out of 13744, taken 1.97 sec per 1 batch
# 11466 img procesed out of 13744, taken 1.98 sec per 1 batch
# 11706 img procesed out of 13744, taken 2.00 sec per 1 batch
# 11946 img procesed out of 13744, taken 2.04 sec per 1 batch
# 12186 img procesed out of 13744, taken 2.15 sec per 1 batch
# 12426 img procesed out of 13744, taken 2.11 sec per 1 batch
# 12666 img procesed out of 13744, taken 2.04 sec per 1 batch
# 12906 img procesed out of 13744, taken 1.99 sec per 1 batch
# 13146 img procesed out of 13744, taken 2.05 sec per 1 batch
# 13386 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 13626 img procesed out of 13744, taken 1.99 sec per 1 batch
# saving the model at the end of epoch 20, iters 45820
# End of epoch 20 / 300 	 Time Taken: 4930.07 sec
# learning rate = 0.0002000
# 120 img procesed out of 13744, taken 2.14 sec per 1 batch
# 360 img procesed out of 13744, taken 2.09 sec per 1 batch
# 600 img procesed out of 13744, taken 2.06 sec per 1 batch
# 840 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1080 img procesed out of 13744, taken 2.34 sec per 1 batch
# 1320 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 1560 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1800 img procesed out of 13744, taken 2.05 sec per 1 batch
# 2040 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2280 img procesed out of 13744, taken 2.06 sec per 1 batch
# 2520 img procesed out of 13744, taken 2.02 sec per 1 batch
# 2760 img procesed out of 13744, taken 2.01 sec per 1 batch
# 3000 img procesed out of 13744, taken 1.99 sec per 1 batch
# 3240 img procesed out of 13744, taken 2.02 sec per 1 batch
# 3480 img procesed out of 13744, taken 2.13 sec per 1 batch
# All values are same
# Try new img
# 3720 img procesed out of 13744, taken 2.04 sec per 1 batch
# 3960 img procesed out of 13744, taken 2.04 sec per 1 batch
# 4200 img procesed out of 13744, taken 2.01 sec per 1 batch
# 4440 img procesed out of 13744, taken 1.98 sec per 1 batch
# 4680 img procesed out of 13744, taken 2.11 sec per 1 batch
# All values are same
# Try new img
# 4920 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 5160 img procesed out of 13744, taken 2.10 sec per 1 batch
# 5400 img procesed out of 13744, taken 2.12 sec per 1 batch
# 5640 img procesed out of 13744, taken 2.05 sec per 1 batch
# 5880 img procesed out of 13744, taken 2.07 sec per 1 batch
# 6120 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 6360 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6600 img procesed out of 13744, taken 2.04 sec per 1 batch
# 6840 img procesed out of 13744, taken 2.16 sec per 1 batch
# 7080 img procesed out of 13744, taken 2.42 sec per 1 batch
# 7320 img procesed out of 13744, taken 2.02 sec per 1 batch
# 7560 img procesed out of 13744, taken 2.04 sec per 1 batch
# 7800 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 8040 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 8280 img procesed out of 13744, taken 2.02 sec per 1 batch
# 8520 img procesed out of 13744, taken 2.02 sec per 1 batch
# 8760 img procesed out of 13744, taken 2.01 sec per 1 batch
# 9000 img procesed out of 13744, taken 2.00 sec per 1 batch
# 9240 img procesed out of 13744, taken 2.00 sec per 1 batch
# 9480 img procesed out of 13744, taken 2.05 sec per 1 batch
# 9720 img procesed out of 13744, taken 2.12 sec per 1 batch
# 9960 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 10200 img procesed out of 13744, taken 2.04 sec per 1 batch
# 10440 img procesed out of 13744, taken 2.00 sec per 1 batch
# 10680 img procesed out of 13744, taken 2.01 sec per 1 batch
# 10920 img procesed out of 13744, taken 1.99 sec per 1 batch
# 11160 img procesed out of 13744, taken 2.01 sec per 1 batch
# 11400 img procesed out of 13744, taken 2.16 sec per 1 batch
# 11640 img procesed out of 13744, taken 2.01 sec per 1 batch
# 11880 img procesed out of 13744, taken 2.01 sec per 1 batch
# 12120 img procesed out of 13744, taken 2.10 sec per 1 batch
# 12360 img procesed out of 13744, taken 2.11 sec per 1 batch
# 12600 img procesed out of 13744, taken 2.10 sec per 1 batch
# 12840 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 13080 img procesed out of 13744, taken 2.33 sec per 1 batch
# 13320 img procesed out of 13744, taken 2.07 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 13560 img procesed out of 13744, taken 2.04 sec per 1 batch
# End of epoch 21 / 300 	 Time Taken: 4928.94 sec
# learning rate = 0.0002000
# 54 img procesed out of 13744, taken 2.07 sec per 1 batch
# 294 img procesed out of 13744, taken 2.11 sec per 1 batch
# 534 img procesed out of 13744, taken 2.11 sec per 1 batch
# 774 img procesed out of 13744, taken 2.00 sec per 1 batch
# 1014 img procesed out of 13744, taken 2.12 sec per 1 batch
# 1254 img procesed out of 13744, taken 2.01 sec per 1 batch
# 1494 img procesed out of 13744, taken 2.07 sec per 1 batch
# All values are same
# Try new img
# 1734 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 1974 img procesed out of 13744, taken 2.00 sec per 1 batch
# 2214 img procesed out of 13744, taken 2.07 sec per 1 batch
# 2454 img procesed out of 13744, taken 2.08 sec per 1 batch
# 2694 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 2934 img procesed out of 13744, taken 2.14 sec per 1 batch
# 3174 img procesed out of 13744, taken 2.04 sec per 1 batch
# All values are same
# Try new img
# 3414 img procesed out of 13744, taken 2.10 sec per 1 batch
# 3654 img procesed out of 13744, taken 1.99 sec per 1 batch
# 3894 img procesed out of 13744, taken 2.11 sec per 1 batch
# All values are same
# Try new img
# 4134 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 4374 img procesed out of 13744, taken 2.03 sec per 1 batch
# 4614 img procesed out of 13744, taken 2.10 sec per 1 batch
# 4854 img procesed out of 13744, taken 2.11 sec per 1 batch
# All values are same
# Try new img
# 5094 img procesed out of 13744, taken 2.00 sec per 1 batch
# 5334 img procesed out of 13744, taken 2.40 sec per 1 batch
# 5574 img procesed out of 13744, taken 2.04 sec per 1 batch
# 5814 img procesed out of 13744, taken 2.04 sec per 1 batch
# 6054 img procesed out of 13744, taken 2.06 sec per 1 batch
# 6294 img procesed out of 13744, taken 2.06 sec per 1 batch
# All values are same
# Try new img
# 6534 img procesed out of 13744, taken 1.99 sec per 1 batch
# 6774 img procesed out of 13744, taken 2.04 sec per 1 batch
# 7014 img procesed out of 13744, taken 2.14 sec per 1 batch
# 7254 img procesed out of 13744, taken 2.01 sec per 1 batch
# 7494 img procesed out of 13744, taken 2.12 sec per 1 batch
# All values are same
# Try new img
# 7734 img procesed out of 13744, taken 2.12 sec per 1 batch
# All values are same
# Try new img
# 7974 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 8214 img procesed out of 13744, taken 2.00 sec per 1 batch
# 8454 img procesed out of 13744, taken 2.00 sec per 1 batch
# 8694 img procesed out of 13744, taken 1.98 sec per 1 batch
# 8934 img procesed out of 13744, taken 2.03 sec per 1 batch
# 9174 img procesed out of 13744, taken 2.09 sec per 1 batch
# 9414 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 9654 img procesed out of 13744, taken 2.01 sec per 1 batch
# 9894 img procesed out of 13744, taken 2.01 sec per 1 batch
# 10134 img procesed out of 13744, taken 2.03 sec per 1 batch
# 10374 img procesed out of 13744, taken 2.08 sec per 1 batch
# 10614 img procesed out of 13744, taken 2.05 sec per 1 batch
# All values are same
# Try new img
# 10854 img procesed out of 13744, taken 1.99 sec per 1 batch
# 11094 img procesed out of 13744, taken 2.06 sec per 1 batch
# 11334 img procesed out of 13744, taken 2.43 sec per 1 batch
# 11574 img procesed out of 13744, taken 2.04 sec per 1 batch
# 11814 img procesed out of 13744, taken 1.98 sec per 1 batch
# 12054 img procesed out of 13744, taken 2.00 sec per 1 batch
# 12294 img procesed out of 13744, taken 2.05 sec per 1 batch
# 12534 img procesed out of 13744, taken 2.06 sec per 1 batch
# 12774 img procesed out of 13744, taken 2.01 sec per 1 batch
# 13014 img procesed out of 13744, taken 2.06 sec per 1 batch
# 13254 img procesed out of 13744, taken 2.15 sec per 1 batch
# 13494 img procesed out of 13744, taken 2.15 sec per 1 batch
# 13734 img procesed out of 13744, taken 2.06 sec per 1 batch
# End of epoch 22 / 300 	 Time Taken: 4928.21 sec
# learning rate = 0.0002000
# 228 img procesed out of 13744, taken 1.99 sec per 1 batch
# 468 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 708 img procesed out of 13744, taken 2.04 sec per 1 batch
# 948 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 1188 img procesed out of 13744, taken 1.99 sec per 1 batch
# All values are same
# Try new img
# 1428 img procesed out of 13744, taken 2.00 sec per 1 batch
# All values are same
# Try new img
# 1668 img procesed out of 13744, taken 2.02 sec per 1 batch
# 1908 img procesed out of 13744, taken 2.11 sec per 1 batch
# 2148 img procesed out of 13744, taken 2.01 sec per 1 batch
# All values are same
# Try new img
# 2388 img procesed out of 13744, taken 2.09 sec per 1 batch
# 2628 img procesed out of 13744, taken 2.13 sec per 1 batch
# All values are same
# Try new img
# 2868 img procesed out of 13744, taken 2.15 sec per 1 batch
# All values are same
# Try new img
# 3108 img procesed out of 13744, taken 2.00 sec per 1 batch
# 3348 img procesed out of 13744, taken 2.07 sec per 1 batch
# 3588 img procesed out of 13744, taken 2.36 sec per 1 batch
# 3828 img procesed out of 13744, taken 2.03 sec per 1 batch
# 4068 img procesed out of 13744, taken 2.06 sec per 1 batch
# 4308 img procesed out of 13744, taken 2.02 sec per 1 batch
# 4548 img procesed out of 13744, taken 2.12 sec per 1 batch
# 4788 img procesed out of 13744, taken 2.05 sec per 1 batch
# 5028 img procesed out of 13744, taken 2.06 sec per 1 batch
# 5268 img procesed out of 13744, taken 2.00 sec per 1 batch
# 5508 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 5748 img procesed out of 13744, taken 1.99 sec per 1 batch
# 5988 img procesed out of 13744, taken 2.04 sec per 1 batch
# 6228 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 6468 img procesed out of 13744, taken 2.07 sec per 1 batch
# 6708 img procesed out of 13744, taken 2.00 sec per 1 batch
# 6948 img procesed out of 13744, taken 2.05 sec per 1 batch
# 7188 img procesed out of 13744, taken 2.05 sec per 1 batch
# 7428 img procesed out of 13744, taken 2.15 sec per 1 batch
# 7668 img procesed out of 13744, taken 2.11 sec per 1 batch
# 7908 img procesed out of 13744, taken 2.13 sec per 1 batch
# 8148 img procesed out of 13744, taken 2.03 sec per 1 batch
# 8388 img procesed out of 13744, taken 2.08 sec per 1 batch
# 8628 img procesed out of 13744, taken 2.01 sec per 1 batch
# 8868 img procesed out of 13744, taken 1.99 sec per 1 batch
# 9108 img procesed out of 13744, taken 2.02 sec per 1 batch
# All values are same
# Try new img
# 9348 img procesed out of 13744, taken 2.03 sec per 1 batch
# 9588 img procesed out of 13744, taken 2.44 sec per 1 batch
# All values are same
# Try new img
# 9828 img procesed out of 13744, taken 2.08 sec per 1 batch
# All values are same
# Try new img
# 10068 img procesed out of 13744, taken 2.15 sec per 1 batch
# 10308 img procesed out of 13744, taken 2.09 sec per 1 batch
# 10548 img procesed out of 13744, taken 2.06 sec per 1 batch
# 10788 img procesed out of 13744, taken 2.14 sec per 1 batch
# 11028 img procesed out of 13744, taken 2.06 sec per 1 batch
# 11268 img procesed out of 13744, taken 2.13 sec per 1 batch
# ^C
# Traceback (most recent call last):
#   File "train.py", line 76, in <module>
#     model.optimize_param()
#   File "/workspace/code/my_cyclegan/models/semi_cycle_gan.py", line 458, in optimize_param
#     self.backward_D_A()
#   File "/workspace/code/my_cyclegan/models/unflow_gan.py", line 30, in backward_D_A
#     self.loss_D_A_normal = self.backward_D_base(self.netD_A_normal, self.real_norm_B, self.fake_norm_B)
#   File "/workspace/code/my_cyclegan/models/semi_cycle_gan.py", line 345, in backward_D_base
#     pred_fake = netD(fake.detach())
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py", line 161, in forward
#     outputs = self.parallel_apply(replicas, inputs, kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py", line 171, in parallel_apply
#     return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py", line 76, in parallel_apply
#     thread.start()
#   File "/opt/conda/lib/python3.7/threading.py", line 857, in start
#     self._started.wait()
#   File "/opt/conda/lib/python3.7/threading.py", line 552, in wait
#     signaled = self._cond.wait(timeout)
#   File "/opt/conda/lib/python3.7/threading.py", line 296, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# wandb: Waiting for W&B process to finish, PID 671
# wandb: Program failed with code 255.  Press ctrl-c to abort syncing.

# %%
# !ls checkpoints/scannet_unflow_bigL_no_idtA_last
# Out:
# 10.pt  15.pt  20.pt  25.pt  5.pt  train_opt.txt

# %%
# !ls /data/unpaired_depth/Scannet_ssim/testB/full_size/img/ | wc -l
# Out:
# 15124

# %%
ls -la

# %%
# !python test.py --name scannet_unflow_bigL_no_idtA_last\
--dataroot /data/unpaired_depth/Scannet_ssim \
--gpu_ids 1\
--load_epoch 15\
--inp_B img_depth\
--use_spnorm\
--batch_size 1\
--phase test\
--use_cycle_A\
--use_cycle_B\
--load_size_h 480\
--load_size_w 640\
--crop_size_h 480\
--crop_size_w 640\
--img_dir bigL_no_idtA_last\
--save_img
# Out:
# self.opt.phase test
# Dataset SemiCycleDataset was created
# The number of training images = 501
# initialize network with xavier
# initialize network with xavier
# model [SemiCycleGANModel] was created
# loading the model from ./checkpoints/scannet_unflow_bigL_no_idtA_last/15.pt
# loading the model from ./checkpoints/scannet_unflow_bigL_no_idtA_last/15.pt
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.620 M
# [Network netG_B] Total number of parameters : 11.620 M
# -----------------------------------------------
# 100%|█████████████████████████████████████████| 501/501 [15:20<00:00,  1.84s/it]
# 0.020±0.009 Difference between real and r2s
# 0.151±0.132 Difference between syn and s2r
#
# 0.147±0.109 Difference between real and cycle real
# 0.063±0.050 Difference between syn and cycle syn
#
# -0.012±0.014 r2s - real
# 0.119±0.158 s2r - syn

# %%
# !ls -la
# Out:
# total 5928
# drwxrwxr-x 14 safin safin    4096 Feb 19 21:56 .
# drwxrwxr-x 33 safin safin    4096 Feb  1 06:46 ..
# drwxr-xr-x  2 root  root     4096 Nov  5 20:11 .empty
# drwxrwxr-x  8 safin safin    4096 Dec  8 20:48 .git
# -rw-rw-r--  1 safin safin    2557 Nov  3 20:25 .gitignore
# drwxrwxr-x  2 safin safin    4096 Feb  2 08:59 .ipynb_checkpoints
# -rw-rw-r--  1 safin safin       0 Dec  3 08:58 __init__.py
# drwxrwxr-x 15 safin safin    4096 Feb 19 15:24 checkpoints
# -rw-rw-r--  1 safin safin  737074 Jan 11 07:14 code_check.ipynb
# drwxrwxr-x  3 safin safin    4096 Feb 19 21:44 dataloader
# -rw-r--r--  1 safin safin   19601 Feb  2 09:01 filter_data.ipynb
# -rw-r--r--  1 safin safin    4765 Dec  3 17:51 filter_scannet.py
# drwxrwxr-x  2 safin safin    4096 Nov  3 20:25 metric
# drwxrwxr-x  4 safin safin    4096 Dec 15 19:30 models
# drwxrwxr-x  3 safin safin    4096 Dec 13 18:10 options
# -rw-rw-r--  1 safin safin     342 Dec  3 08:58 print_model.py
# -rw-rw-r--  1 safin safin   17392 Nov  3 20:25 run4.ipynb
# -rw-rw-r--  1 safin safin   24421 Jan 11 12:26 run_1.ipynb
# -rw-rw-r--  1 safin safin   53139 Jan 11 12:26 run_2.ipynb
# -rw-rw-r--  1 safin safin   21944 Jan 11 12:17 run_3.ipynb
# -rw-r--r--  1 safin safin   20204 Jan 11 12:15 run_flow_gpu2-Copy1.ipynb
# -rw-r--r--  1 safin safin   69743 Jan  9 20:54 run_flow_gpu2-Copy2.ipynb
# -rw-rw-r--  1 safin safin   42166 Feb 19 20:59 run_flow_gpu2.ipynb
# -rw-rw-r--  1 safin safin  283620 Nov  3 20:25 run_hole.ipynb
# -rw-r--r--  1 safin safin 3986584 Feb 19 21:16 scannet_filtering.ipynb
# drwxr-xr-x  3 safin safin    4096 Dec  7 17:51 scannet_paired_out
# -rw-rw-r--  1 safin safin    2628 Dec  3 08:58 test.py
# -rw-rw-r--  1 safin safin    4655 Dec 13 17:58 train.py
# -rw-rw-r--  1 safin safin    4793 Nov  3 20:25 train_opt.txt
# -rw-r--r--  1 safin safin  434150 Feb 19 21:56 unflow-2021.ipynb
# -rw-r--r--  1 safin safin   35505 Dec 17 17:47 unflow.ipynb
# drwxr-xr-x  3 safin safin    4096 Jan 11 13:23 unflow_bigL_w_idtA
# -rw-r--r--  1 safin safin  207106 Jan 14 07:23 unflow_gpu23.ipynb
# drwxrwxr-x  3 safin safin    4096 Dec 13 19:01 utils
# drwxr-xr-x 16 safin safin    4096 Feb 19 21:44 wandb

# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/Scannet_ssim \
--name scannet_unflow_bigL_no_idtA_last \
--gpu_ids 1,3\
--batch_size 6\
--model unflow_gan\
--crop_size_h 256\
--crop_size_w 256\
--load_size_h 320\
--load_size_w 320\
--num_iter_gen 3\
--disc_for_normals\
--disc_for_depth\
--use_spnorm\
--use_cycle_B\
--l_depth_A_begin 10\
--l_depth_A_end 10\
--l_depth_B_begin 10\
--l_depth_B_end 10\
--l_cycle_B_begin 50.\
--l_cycle_B_end 50.\
--l_identity 1.0\
--no_idt_A\
--l_normal 1000.\
--data_shuffle\
--max_dataset_size 60000\
--init_type normal\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 5\
--n_epochs 100\
--n_epochs_decay 10\
--norm_d none \
--inp_B img_depth
# Out:
# ----------------- Options ---------------
#                batch_size: 6                             	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 256                           	[default: 240]
#               crop_size_w: 256                           	[default: 320]
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/Scannet_ssim	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: True                          	[default: False]
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 1,3                           	[default: 1,2]
#               hole_border: -0.97
#             img2depth_dir: ./checkpoints/img2d_pretrain/
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal                        	[default: xavier]
#                     inp_B: img_depth                     	[default: depth]
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0
#             l_cycle_A_end: 10.0
#           l_cycle_B_begin: 50.0                          	[default: 10.0]
#             l_cycle_B_end: 50.0                          	[default: 10.0]
#           l_depth_A_begin: 10.0                          	[default: 5.0]
#             l_depth_A_end: 10.0                          	[default: 0.0]
#           l_depth_B_begin: 10.0                          	[default: 5.0]
#             l_depth_B_end: 10.0                          	[default: 0.0]
#                  l_hole_A: 0.0
#                l_identity: 1.0                           	[default: 0.0]
#                l_max_iter: 5000
#                  l_mean_A: 0.0
#                  l_mean_B: 0.0
#                  l_normal: 1000.0                        	[default: 10.0]
#                l_num_iter: 5000
# l_reconstruction_semantic: 0.0
#                    l_tv_A: 0.0
#                load_epoch: last
#      load_epoch_img2depth: last
#        load_epoch_weights: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 320                           	[default: 480]
#               load_size_w: 320                           	[default: 640]
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 60000                         	[default: inf]
#              max_distance: 5100.0
#                     model: unflow_gan                    	[default: semi_cycle_gan]
#                  n_blocks: 9
#            n_downsampling: 2
#                  n_epochs: 100                           	[default: 1]
#            n_epochs_decay: 10                            	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: scannet_unflow_bigL_no_idtA_last	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32
#                   ngf_img: 32
#           ngf_img_feature: 32
#                  no_idt_A: True                          	[default: False]
#                      norm: group
#                    norm_d: none                          	[default: instance]
#              num_iter_dis: 1
#              num_iter_gen: 3                             	[default: 1]
#               num_workers: 4
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 5                             	[default: 10]
#           upsampling_type: transpose
#               use_cycle_A: False
#               use_cycle_B: True                          	[default: False]
#         use_mean_matching: False
#    use_pretrain_img2depth: False
#      use_pretrain_weights: False
#              use_semantic: False
#      use_semi_cycle_first: False
#     use_semi_cycle_second: False
#                use_spnorm: True                          	[default: False]
#                   verbose: False
#                 w_decay_G: 0.0001
#               weights_dir: ./checkpoints/pretrain_weights_imgdepht/
# ----------------- End -------------------
# wandb: Currently logged in as: blaabl (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.18 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.11
# wandb: Syncing run scannet_unflow_bigL_no_idtA_last
# wandb: ⭐️ View project at https://wandb.ai/blaabl/un_depth
# wandb: 🚀 View run at https://wandb.ai/blaabl/un_depth/runs/1alzsd7u
# wandb: Run data is saved locally in /workspace/code/my_cyclegan/wandb/run-20210213_214914-1alzsd7u
# wandb: Run `wandb offline` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 37986
# Dataset SemiCycleDataset was created
# The number of test images = 15123
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [UnFlowGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.620 M
# [Network netG_B] Total number of parameters : 11.620 M
# [Network netD_A_depth] Total number of parameters : 2.762 M
# [Network netD_B_depth] Total number of parameters : 2.762 M
# [Network netD_A_normal] Total number of parameters : 2.764 M
# [Network netD_B_normal] Total number of parameters : 2.764 M
# -----------------------------------------------
# 240 img procesed out of 37986, taken 1.91 sec per 1 batch
# 480 img procesed out of 37986, taken 1.94 sec per 1 batch
# 720 img procesed out of 37986, taken 1.91 sec per 1 batch
# 960 img procesed out of 37986, taken 1.96 sec per 1 batch
# 1200 img procesed out of 37986, taken 1.94 sec per 1 batch
# 1440 img procesed out of 37986, taken 1.93 sec per 1 batch
# 1680 img procesed out of 37986, taken 1.97 sec per 1 batch
# 1920 img procesed out of 37986, taken 1.93 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 2160 img procesed out of 37986, taken 1.95 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# All values are same
# Try new img
# 2400 img procesed out of 37986, taken 1.94 sec per 1 batch
# All values are same
# Try new img
# 2640 img procesed out of 37986, taken 1.91 sec per 1 batch
# All values are same
# Try new img
# 2880 img procesed out of 37986, taken 1.94 sec per 1 batch
# 3120 img procesed out of 37986, taken 1.94 sec per 1 batch
# All values are same
# Try new img
# 3360 img procesed out of 37986, taken 1.94 sec per 1 batch
# 3600 img procesed out of 37986, taken 1.94 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 3840 img procesed out of 37986, taken 1.91 sec per 1 batch
# 4080 img procesed out of 37986, taken 1.93 sec per 1 batch
# 4320 img procesed out of 37986, taken 1.97 sec per 1 batch
# All values are same
# Try new img
# 4560 img procesed out of 37986, taken 1.95 sec per 1 batch
# All values are same
# Try new img
# All values are same
# Try new img
# 4800 img procesed out of 37986, taken 1.96 sec per 1 batch
# 5040 img procesed out of 37986, taken 1.94 sec per 1 batch
# All values are same
# Try new img
# 5280 img procesed out of 37986, taken 1.96 sec per 1 batch
# All values are same
# Try new img
# 5520 img procesed out of 37986, taken 1.90 sec per 1 batch
# 5760 img procesed out of 37986, taken 1.91 sec per 1 batch
# 6000 img procesed out of 37986, taken 2.22 sec per 1 batch
# All values are same
# Try new img
# 6240 img procesed out of 37986, taken 1.92 sec per 1 batch
# 6480 img procesed out of 37986, taken 1.95 sec per 1 batch
# 6720 img procesed out of 37986, taken 1.96 sec per 1 batch
# All values are same
# Try new img

# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/Scannet_cleaned \
--name scannet_unflow_unpaired \
--gpu_ids 0,1,2,3\
--batch_size 48\
--model unflow_gan\
--crop_size_h 128\
--crop_size_w 128\
--load_size_h 192\
--load_size_w 192\
--num_iter_gen 3\
--disc_for_normals\
--disc_for_depth\
--use_spnorm\
--use_cycle_B\
--l_depth_A_begin 0\
--l_depth_A_end 0\
--l_depth_B_begin 1\
--l_depth_B_end 1\
--l_cycle_A_begin 10.\
--l_cycle_A_end 10.\
--l_cycle_B_begin 10.\
--l_cycle_B_end 10.\
--l_identity 5.0\
--l_normal 20.\
--data_shuffle\
--max_dataset_size 60000\
--init_type  normal\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 5\
--n_epochs 100\
--n_epochs_decay 5\
--norm_d none \
--inp_B img_depth
# Out:
# ----------------- Options ---------------
#                batch_size: 48                            	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 128                           	[default: 240]
#               crop_size_w: 128                           	[default: 320]
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/Scannet_cleaned	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: True                          	[default: False]
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0,1,2,3                       	[default: 1,2]
#               hole_border: -0.97
#             img2depth_dir: ./checkpoints/img2d_pretrain/
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal                        	[default: xavier]
#                     inp_B: img_depth                     	[default: depth]
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0
#             l_cycle_A_end: 10.0
#           l_cycle_B_begin: 10.0
#             l_cycle_B_end: 10.0
#           l_depth_A_begin: 0.0                           	[default: 5.0]
#             l_depth_A_end: 0.0
#           l_depth_B_begin: 1.0                           	[default: 5.0]
#             l_depth_B_end: 1.0                           	[default: 0.0]
#                  l_hole_A: 0.0
#                l_identity: 5.0                           	[default: 0.0]
#                l_max_iter: 5000
#                  l_mean_A: 0.0
#                  l_mean_B: 0.0
#                  l_normal: 20.0                          	[default: 10.0]
#                l_num_iter: 5000
# l_reconstruction_semantic: 0.0
#                    l_tv_A: 0.0
#                load_epoch: last
#      load_epoch_img2depth: last
#        load_epoch_weights: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 192                           	[default: 480]
#               load_size_w: 192                           	[default: 640]
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 60000                         	[default: inf]
#              max_distance: 8000.0
#                     model: unflow_gan                    	[default: semi_cycle_gan]
#                  n_blocks: 9
#            n_downsampling: 2
#                  n_epochs: 100                           	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: scannet_unflow_unpaired       	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32
#                   ngf_img: 32
#           ngf_img_feature: 32
#                      norm: group
#                    norm_d: none                          	[default: instance]
#              num_iter_dis: 1
#              num_iter_gen: 3                             	[default: 1]
#               num_workers: 4
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 5                             	[default: 10]
#           upsampling_type: transpose
#               use_cycle_A: False
#               use_cycle_B: True                          	[default: False]
#         use_mean_matching: False
#    use_pretrain_img2depth: False
#      use_pretrain_weights: False
#              use_semantic: False
#      use_semi_cycle_first: False
#     use_semi_cycle_second: False
#                use_spnorm: True                          	[default: False]
#                   verbose: False
#                 w_decay_G: 0.0001
#               weights_dir: ./checkpoints/pretrain_weights_imgdepht/
# ----------------- End -------------------
# wandb: Currently logged in as: blaabl (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.11
# wandb: Syncing run scannet_unflow_unpaired
# wandb: ⭐️ View project at https://wandb.ai/blaabl/un_depth
# wandb: 🚀 View run at https://wandb.ai/blaabl/un_depth/runs/3c9dejxs
# wandb: Run data is saved locally in /workspace/code/my_cyclegan/wandb/run-20201213_190120-3c9dejxs
# wandb: Run `wandb offline` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 60000
# Dataset SemiCycleDataset was created
# The number of test images = 46567
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [UnFlowGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.620 M
# [Network netG_B] Total number of parameters : 11.620 M
# [Network netD_A_depth] Total number of parameters : 2.762 M
# [Network netD_B_depth] Total number of parameters : 2.762 M
# [Network netD_A_normal] Total number of parameters : 2.764 M
# [Network netD_B_normal] Total number of parameters : 2.764 M
# -----------------------------------------------
# 1920 img procesed out of 60000, taken 2.25 sec per 1 batch
# 3840 img procesed out of 60000, taken 2.31 sec per 1 batch
# 5760 img procesed out of 60000, taken 2.41 sec per 1 batch
# 7680 img procesed out of 60000, taken 2.29 sec per 1 batch
# 9600 img procesed out of 60000, taken 2.36 sec per 1 batch
# 11520 img procesed out of 60000, taken 2.29 sec per 1 batch
# 13440 img procesed out of 60000, taken 2.32 sec per 1 batch
# 15360 img procesed out of 60000, taken 2.32 sec per 1 batch
# 17280 img procesed out of 60000, taken 2.31 sec per 1 batch
# 19200 img procesed out of 60000, taken 2.30 sec per 1 batch
# 21120 img procesed out of 60000, taken 2.29 sec per 1 batch
# 23040 img procesed out of 60000, taken 2.28 sec per 1 batch
# 24960 img procesed out of 60000, taken 2.29 sec per 1 batch
# 26880 img procesed out of 60000, taken 2.44 sec per 1 batch
# 28800 img procesed out of 60000, taken 2.30 sec per 1 batch
# 30720 img procesed out of 60000, taken 2.29 sec per 1 batch
# 32640 img procesed out of 60000, taken 2.29 sec per 1 batch
# 34560 img procesed out of 60000, taken 2.32 sec per 1 batch
# 36480 img procesed out of 60000, taken 2.30 sec per 1 batch
# 38400 img procesed out of 60000, taken 2.33 sec per 1 batch
# 40320 img procesed out of 60000, taken 2.32 sec per 1 batch
# 42240 img procesed out of 60000, taken 2.32 sec per 1 batch
# 44160 img procesed out of 60000, taken 2.34 sec per 1 batch
# 46080 img procesed out of 60000, taken 2.32 sec per 1 batch
# 48000 img procesed out of 60000, taken 2.59 sec per 1 batch
# 49920 img procesed out of 60000, taken 2.31 sec per 1 batch
# 51840 img procesed out of 60000, taken 2.28 sec per 1 batch
# 53760 img procesed out of 60000, taken 2.31 sec per 1 batch
# 55680 img procesed out of 60000, taken 2.31 sec per 1 batch
# 57600 img procesed out of 60000, taken 2.34 sec per 1 batch
# 59520 img procesed out of 60000, taken 2.30 sec per 1 batch
# End of epoch 1 / 105 	 Time Taken: 3080.22 sec
# learning rate = 0.0002000
# 1440 img procesed out of 60000, taken 2.34 sec per 1 batch
# 3360 img procesed out of 60000, taken 2.34 sec per 1 batch
# 5280 img procesed out of 60000, taken 2.32 sec per 1 batch
# 7200 img procesed out of 60000, taken 2.28 sec per 1 batch
# 9120 img procesed out of 60000, taken 2.29 sec per 1 batch
# 11040 img procesed out of 60000, taken 2.30 sec per 1 batch
# 12960 img procesed out of 60000, taken 2.29 sec per 1 batch
# 14880 img procesed out of 60000, taken 2.29 sec per 1 batch
# 16800 img procesed out of 60000, taken 2.40 sec per 1 batch
# 18720 img procesed out of 60000, taken 2.31 sec per 1 batch
# 20640 img procesed out of 60000, taken 2.32 sec per 1 batch
# 22560 img procesed out of 60000, taken 2.30 sec per 1 batch
# 24480 img procesed out of 60000, taken 2.35 sec per 1 batch
# 26400 img procesed out of 60000, taken 2.29 sec per 1 batch
# 28320 img procesed out of 60000, taken 2.35 sec per 1 batch
# 30240 img procesed out of 60000, taken 2.30 sec per 1 batch
# 32160 img procesed out of 60000, taken 2.31 sec per 1 batch
# 34080 img procesed out of 60000, taken 2.30 sec per 1 batch
# 36000 img procesed out of 60000, taken 2.55 sec per 1 batch
# 37920 img procesed out of 60000, taken 2.33 sec per 1 batch
# 39840 img procesed out of 60000, taken 2.32 sec per 1 batch
# 41760 img procesed out of 60000, taken 2.30 sec per 1 batch
# 43680 img procesed out of 60000, taken 2.29 sec per 1 batch
# 45600 img procesed out of 60000, taken 2.29 sec per 1 batch
# 47520 img procesed out of 60000, taken 2.30 sec per 1 batch
# 49440 img procesed out of 60000, taken 2.28 sec per 1 batch
# 51360 img procesed out of 60000, taken 2.36 sec per 1 batch
# 53280 img procesed out of 60000, taken 2.39 sec per 1 batch
# 55200 img procesed out of 60000, taken 2.28 sec per 1 batch
# 57120 img procesed out of 60000, taken 2.33 sec per 1 batch
# 59040 img procesed out of 60000, taken 2.42 sec per 1 batch
# End of epoch 2 / 105 	 Time Taken: 3081.41 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 2.31 sec per 1 batch
# 2880 img procesed out of 60000, taken 2.32 sec per 1 batch
# 4800 img procesed out of 60000, taken 2.29 sec per 1 batch
# 6720 img procesed out of 60000, taken 2.27 sec per 1 batch
# 8640 img procesed out of 60000, taken 2.29 sec per 1 batch
# 10560 img procesed out of 60000, taken 2.30 sec per 1 batch
# 12480 img procesed out of 60000, taken 2.31 sec per 1 batch
# 14400 img procesed out of 60000, taken 2.30 sec per 1 batch
# 16320 img procesed out of 60000, taken 2.31 sec per 1 batch
# 18240 img procesed out of 60000, taken 2.30 sec per 1 batch
# 20160 img procesed out of 60000, taken 2.30 sec per 1 batch
# 22080 img procesed out of 60000, taken 2.30 sec per 1 batch
# 24000 img procesed out of 60000, taken 2.61 sec per 1 batch
# 25920 img procesed out of 60000, taken 2.29 sec per 1 batch
# 27840 img procesed out of 60000, taken 2.29 sec per 1 batch
# 29760 img procesed out of 60000, taken 2.30 sec per 1 batch
# 31680 img procesed out of 60000, taken 2.35 sec per 1 batch
# 33600 img procesed out of 60000, taken 2.33 sec per 1 batch
# 35520 img procesed out of 60000, taken 2.34 sec per 1 batch
# 37440 img procesed out of 60000, taken 2.31 sec per 1 batch
# 39360 img procesed out of 60000, taken 2.40 sec per 1 batch
# 41280 img procesed out of 60000, taken 2.35 sec per 1 batch
# 43200 img procesed out of 60000, taken 2.33 sec per 1 batch
# 45120 img procesed out of 60000, taken 2.33 sec per 1 batch
# 47040 img procesed out of 60000, taken 2.36 sec per 1 batch
# 48960 img procesed out of 60000, taken 2.31 sec per 1 batch
# 50880 img procesed out of 60000, taken 2.29 sec per 1 batch
# 52800 img procesed out of 60000, taken 2.30 sec per 1 batch
# 54720 img procesed out of 60000, taken 2.27 sec per 1 batch
# 56640 img procesed out of 60000, taken 2.32 sec per 1 batch
# 58560 img procesed out of 60000, taken 2.31 sec per 1 batch
# End of epoch 3 / 105 	 Time Taken: 3081.73 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 2.27 sec per 1 batch
# 2400 img procesed out of 60000, taken 2.42 sec per 1 batch
# 4320 img procesed out of 60000, taken 2.33 sec per 1 batch
