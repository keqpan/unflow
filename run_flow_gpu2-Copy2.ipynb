# %%
import os
os.chdir('/workspace/code/my_cyclegan')

# %%
# !ls
# Out:
# redwood  testA	testB  trainA  trainB  valA  valB

# %%
import imageio

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(imageio.imread("/data/unpaired_depth/Scannet_cleaned/trainA/depth/scene0002_00_3650_3.png"))

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"

# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/Scannet_cleaned \
--name scannet_unpaired \
--gpu_ids 0,1,2,3\
--batch_size 60\
--crop_size_h 128\
--crop_size_w 128\
--load_size_h 192\
--load_size_w 192\
--num_iter_gen 3\
--disc_for_normals\
--use_spnorm\
--use_cycle_A\
--use_cycle_B\
--l_depth_A_begin 0\
--l_depth_A_end 0\
--l_depth_B_begin 0\
--l_depth_B_end 0\
--l_cycle_A_begin 10.\
--l_cycle_A_end 10.\
--l_cycle_B_begin 10.\
--l_cycle_B_end 10.\
--l_identity 5.0\
--l_normal 20.\
--data_shuffle\
--max_dataset_size 60000\
--init_type  normal\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 5\
--n_epochs 100\
--n_epochs_decay 5\
--norm_d none \
--inp_B img_depth
# Out:
# ----------------- Options ---------------
#                batch_size: 60                            	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 128                           	[default: 240]
#               crop_size_w: 128                           	[default: 320]
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/Scannet_cleaned	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: False
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0,1,2,3                       	[default: 1,2]
#               hole_border: -0.97
# ...

# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/Scannet_cleaned \
--name scannet_unpaired \
--gpu_ids 0,1,2,3\
--batch_size 60\
--crop_size_h 128\
--crop_size_w 128\
--load_size_h 192\
--load_size_w 192\
--num_iter_gen 3\
--disc_for_normals\
--use_spnorm\
--use_cycle_A\
--use_cycle_B\
--l_depth_A_begin 1.\
--l_depth_A_end 1.\
--l_depth_B_begin 1\
--l_depth_B_end 1\
--l_cycle_A_begin 10.\
--l_cycle_A_end 10.\
--l_cycle_B_begin 10.\
--l_cycle_B_end 10.\
--l_identity 0.\
--l_normal 20.\
--l_mean_A 0.\
--l_mean_B 0.\
--l_max_iter 30000\
--l_num_iter 20000\
--max_dataset_size 50000\
--init_type  normal\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 2\
--n_epochs 40\
--n_epochs_decay 5\
--norm_d none \
--inp_B img_depth
# Out:
# ----------------- Options ---------------
#                batch_size: 60                            	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 128                           	[default: 240]
#               crop_size_w: 128                           	[default: 320]
#              data_shuffle: False
#                  dataroot: /data/unpaired_depth/Scannet_cleaned	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: False
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0,1,2,3                       	[default: 1,2]
#               hole_border: -0.97
# ...

# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/Scannet_cleaned \
--name scannet_paired \
--gpu_ids 0,1,2,3\
--batch_size 36\
--crop_size_h 128\
--crop_size_w 128\
--load_size_h 192\
--load_size_w 192\
--num_iter_gen 3\
--use_cycle_A\
--use_cycle_B\
--disc_for_normals\
--init_type normal\
--l_depth_A_begin 0\
--l_depth_A_end 0\
--l_depth_B_begin 0\
--l_depth_B_end 0\
--l_cycle_A_begin 10.0\
--l_cycle_A_end 10.0\
--l_cycle_B_begin 10.0\
--l_cycle_B_end 10.0\
--l_identity 5.0\
--data_shuffle\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 10\
--n_epochs 1000\
--n_epochs_decay 5\
# Out:
# ----------------- Options ---------------
#                batch_size: 36                            	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 128                           	[default: 240]
#               crop_size_w: 128                           	[default: 320]
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/Scannet_cleaned	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: False
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0,1,2,3                       	[default: 1,2]
#               hole_border: -0.97
# ...

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
# --gpu_ids 2,3\
# --name try_second_cycle_upconv\
# --use_second_cycle\
# --gan_mode lsgan\
# --upsampling_type upconv\
# --n_blocks 9\
# --n_downsampling 2\
# --ngf_depth 32\
# --ngf_img 32\
# --ndf 64\
# --netD n_layers\
# --n_layers_D 3\
# --l_depth_A_begin 0\
# --l_depth_A_end 0\
# --l_depth_B_begin 0\
# --l_depth_B_end 0\
# --l_depth_max_iter 10000\
# --l_cycle_A_begin 10.0\
# --l_cycle_A_end 10.0\
# --l_cycle_B_begin 10.0\
# --l_cycle_B_end 10.0\
# --l_identity 0\
# --max_dataset_size 20000\
# --data_shuffle\
# --batch_size 8\
# --lr_D 0.0002\
# --lr_G 0.0001\
# --num_iter_gen 1\
# --norm instance\
# --init_type normal\
# --beta1 0.5\
# --img_freq 40\
# --loss_freq 30\
# --save_epoch_freq 3\
# --n_epochs 10\
# --n_epochs_decay 5
# Out:
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 5]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#              data_shuffle: True                          	[default: False]
#                  dataroot: /all_data/hdd/un_depth/semi/sample
#              dataset_mode: semi_cycle
#          disc_for_normals: False
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2,3                           	[default: 2]
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0                          	[default: 1.0]
# ...

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
# --model A2B\
# --gpu_ids 0\
# --name a2b_uptranspose\
# --gan_mode lsgan\
# --upsampling_type transpose\
# --n_blocks 9\
# --n_downsampling 3\
# --ngf_depth 20\
# --ngf_img 32\
# --ndf 64\
# --netD n_layers\
# --n_layers_D 3\
# --l_depth_A_begin 1\
# --l_depth_A_end 1\
# --l_gan_loss 2\
# --l_depth_max_iter 30000\
# --max_dataset_size 20000\
# --batch_size 7\
# --lr_D 0.0001\
# --lr_G 0.0005\
# --num_iter_gen 3\
# --norm instance\
# --init_type xavier\
# --beta1 0.5\
# --img_freq 40\
# --loss_freq 30\
# --save_epoch_freq 2\
# --n_epochs 20\
# --n_epochs_decay 5\
# # --netG_d2e unet_256\
# # --net_d2e_weights './checkpoints/depth_edge_unet_1.5_weight_binatyloss/last_netG_B.pth'\
