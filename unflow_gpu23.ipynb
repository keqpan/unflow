# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/Scannet_cleaned \
--name scannet_unflow_bigL_w_idtA_w_depthA \
--gpu_ids 2,3\
--batch_size 24\
--model unflow_gan\
--crop_size_h 128\
--crop_size_w 128\
--load_size_h 192\
--load_size_w 192\
--num_iter_gen 1\
--disc_for_normals\
--disc_for_depth\
--use_spnorm\
--use_cycle_B\
--l_depth_A_begin 10\
--l_depth_A_end 10\
--l_depth_B_begin 10\
--l_depth_B_end 10\
--l_cycle_B_begin 50.\
--l_cycle_B_end 50.\
--l_identity 1.0\
--l_normal 1000.\
--data_shuffle\
--max_dataset_size 60000\
--init_type normal\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 5\
--n_epochs 100\
--n_epochs_decay 10\
--norm_d none \
--inp_B img_depth
# Out:
# ----------------- Options ---------------
#                batch_size: 24                            	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 128                           	[default: 240]
#               crop_size_w: 128                           	[default: 320]
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/Scannet_cleaned	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: True                          	[default: False]
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2,3                           	[default: 1,2]
#               hole_border: -0.97
#             img2depth_dir: ./checkpoints/img2d_pretrain/
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal                        	[default: xavier]
#                     inp_B: img_depth                     	[default: depth]
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0
#             l_cycle_A_end: 10.0
#           l_cycle_B_begin: 50.0                          	[default: 10.0]
#             l_cycle_B_end: 50.0                          	[default: 10.0]
#           l_depth_A_begin: 10.0                          	[default: 5.0]
#             l_depth_A_end: 10.0                          	[default: 0.0]
#           l_depth_B_begin: 10.0                          	[default: 5.0]
#             l_depth_B_end: 10.0                          	[default: 0.0]
#                  l_hole_A: 0.0
#                l_identity: 1.0                           	[default: 0.0]
#                l_max_iter: 5000
#                  l_mean_A: 0.0
#                  l_mean_B: 0.0
#                  l_normal: 1000.0                        	[default: 10.0]
#                l_num_iter: 5000
# l_reconstruction_semantic: 0.0
#                    l_tv_A: 0.0
#                load_epoch: last
#      load_epoch_img2depth: last
#        load_epoch_weights: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 192                           	[default: 480]
#               load_size_w: 192                           	[default: 640]
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 60000                         	[default: inf]
#              max_distance: 8000.0
#                     model: unflow_gan                    	[default: semi_cycle_gan]
#                  n_blocks: 9
#            n_downsampling: 2
#                  n_epochs: 100                           	[default: 1]
#            n_epochs_decay: 10                            	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: scannet_unflow_bigL_w_idtA_w_depthA	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32
#                   ngf_img: 32
#           ngf_img_feature: 32
#                  no_idt_A: False
#                      norm: group
#                    norm_d: none                          	[default: instance]
#              num_iter_dis: 1
#              num_iter_gen: 1
#               num_workers: 4
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 5                             	[default: 10]
#           upsampling_type: transpose
#               use_cycle_A: False
#               use_cycle_B: True                          	[default: False]
#         use_mean_matching: False
#    use_pretrain_img2depth: False
#      use_pretrain_weights: False
#              use_semantic: False
#      use_semi_cycle_first: False
#     use_semi_cycle_second: False
#                use_spnorm: True                          	[default: False]
#                   verbose: False
#                 w_decay_G: 0.0001
#               weights_dir: ./checkpoints/pretrain_weights_imgdepht/
# ----------------- End -------------------
# wandb: Currently logged in as: blaabl (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.13 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.11
# wandb: Syncing run scannet_unflow_bigL_w_idtA_w_depthA
# wandb: ⭐️ View project at https://wandb.ai/blaabl/un_depth
# wandb: 🚀 View run at https://wandb.ai/blaabl/un_depth/runs/11xshetd
# wandb: Run data is saved locally in /workspace/code/my_cyclegan/wandb/run-20210111_210446-11xshetd
# wandb: Run `wandb offline` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 60000
# Dataset SemiCycleDataset was created
# The number of test images = 46567
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [UnFlowGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.620 M
# [Network netG_B] Total number of parameters : 11.620 M
# [Network netD_A_depth] Total number of parameters : 2.762 M
# [Network netD_B_depth] Total number of parameters : 2.762 M
# [Network netD_A_normal] Total number of parameters : 2.764 M
# [Network netD_B_normal] Total number of parameters : 2.764 M
# -----------------------------------------------
# 960 img procesed out of 60000, taken 1.14 sec per 1 batch
# 1920 img procesed out of 60000, taken 1.23 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.77 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.77 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.78 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.80 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.79 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.78 sec per 1 batch
# 12480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.77 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.80 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.79 sec per 1 batch
# 20160 img procesed out of 60000, taken 1.25 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.97 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.93 sec per 1 batch
# 23040 img procesed out of 60000, taken 1.29 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.37 sec per 1 batch
# 24960 img procesed out of 60000, taken 1.16 sec per 1 batch
# 25920 img procesed out of 60000, taken 1.17 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.98 sec per 1 batch
# 27840 img procesed out of 60000, taken 1.16 sec per 1 batch
# 28800 img procesed out of 60000, taken 1.06 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.97 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.90 sec per 1 batch
# 31680 img procesed out of 60000, taken 1.05 sec per 1 batch
# 32640 img procesed out of 60000, taken 1.19 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.80 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.80 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.76 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 40320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 41280 img procesed out of 60000, taken 0.77 sec per 1 batch
# 42240 img procesed out of 60000, taken 0.78 sec per 1 batch
# 43200 img procesed out of 60000, taken 0.79 sec per 1 batch
# 44160 img procesed out of 60000, taken 0.77 sec per 1 batch
# 45120 img procesed out of 60000, taken 0.83 sec per 1 batch
# 46080 img procesed out of 60000, taken 0.74 sec per 1 batch
# 47040 img procesed out of 60000, taken 0.92 sec per 1 batch
# 48000 img procesed out of 60000, taken 1.05 sec per 1 batch
# 48960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 49920 img procesed out of 60000, taken 0.79 sec per 1 batch
# 50880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 51840 img procesed out of 60000, taken 0.75 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.81 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.77 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.80 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.82 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.78 sec per 1 batch
# End of epoch 1 / 110 	 Time Taken: 2549.23 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.81 sec per 1 batch
# 1440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 2400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 3360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 4320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 5280 img procesed out of 60000, taken 0.81 sec per 1 batch
# 6240 img procesed out of 60000, taken 0.83 sec per 1 batch
# 7200 img procesed out of 60000, taken 0.79 sec per 1 batch
# 8160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 9120 img procesed out of 60000, taken 0.82 sec per 1 batch
# 10080 img procesed out of 60000, taken 0.76 sec per 1 batch
# 11040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 12000 img procesed out of 60000, taken 1.07 sec per 1 batch
# 12960 img procesed out of 60000, taken 0.82 sec per 1 batch
# 13920 img procesed out of 60000, taken 0.76 sec per 1 batch
# 14880 img procesed out of 60000, taken 0.83 sec per 1 batch
# 15840 img procesed out of 60000, taken 0.80 sec per 1 batch
# 16800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 17760 img procesed out of 60000, taken 0.82 sec per 1 batch
# 18720 img procesed out of 60000, taken 0.76 sec per 1 batch
# 19680 img procesed out of 60000, taken 0.81 sec per 1 batch
# 20640 img procesed out of 60000, taken 0.80 sec per 1 batch
# 21600 img procesed out of 60000, taken 0.78 sec per 1 batch
# 22560 img procesed out of 60000, taken 0.78 sec per 1 batch
# 23520 img procesed out of 60000, taken 0.78 sec per 1 batch
# 24480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 25440 img procesed out of 60000, taken 0.80 sec per 1 batch
# 26400 img procesed out of 60000, taken 0.81 sec per 1 batch
# 27360 img procesed out of 60000, taken 0.81 sec per 1 batch
# 28320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 29280 img procesed out of 60000, taken 1.00 sec per 1 batch
# 30240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 31200 img procesed out of 60000, taken 0.79 sec per 1 batch
# 32160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 33120 img procesed out of 60000, taken 0.81 sec per 1 batch
# 34080 img procesed out of 60000, taken 0.77 sec per 1 batch
# 35040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 36000 img procesed out of 60000, taken 1.06 sec per 1 batch
# 36960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 37920 img procesed out of 60000, taken 1.00 sec per 1 batch
# 38880 img procesed out of 60000, taken 0.82 sec per 1 batch
# 39840 img procesed out of 60000, taken 0.79 sec per 1 batch
# 40800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 41760 img procesed out of 60000, taken 0.81 sec per 1 batch
# 42720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 43680 img procesed out of 60000, taken 0.81 sec per 1 batch
# 44640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 45600 img procesed out of 60000, taken 0.80 sec per 1 batch
# 46560 img procesed out of 60000, taken 0.82 sec per 1 batch
# 47520 img procesed out of 60000, taken 0.80 sec per 1 batch
# 48480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 49440 img procesed out of 60000, taken 0.83 sec per 1 batch
# 50400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 51360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 52320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 53280 img procesed out of 60000, taken 0.77 sec per 1 batch
# 54240 img procesed out of 60000, taken 0.81 sec per 1 batch
# 55200 img procesed out of 60000, taken 0.81 sec per 1 batch
# 56160 img procesed out of 60000, taken 0.78 sec per 1 batch
# 57120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 58080 img procesed out of 60000, taken 0.79 sec per 1 batch
# 59040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 60000 img procesed out of 60000, taken 1.14 sec per 1 batch
# End of epoch 2 / 110 	 Time Taken: 2377.92 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 1920 img procesed out of 60000, taken 0.78 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.75 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.80 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.75 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.79 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.81 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.79 sec per 1 batch
# 12480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.80 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.82 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.99 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 20160 img procesed out of 60000, taken 0.78 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.97 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.80 sec per 1 batch
# 23040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.08 sec per 1 batch
# 24960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 25920 img procesed out of 60000, taken 0.80 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 27840 img procesed out of 60000, taken 0.82 sec per 1 batch
# 28800 img procesed out of 60000, taken 0.81 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.81 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.80 sec per 1 batch
# 31680 img procesed out of 60000, taken 0.80 sec per 1 batch
# 32640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.79 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.81 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.81 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.84 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.81 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 40320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 41280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 42240 img procesed out of 60000, taken 0.99 sec per 1 batch
# 43200 img procesed out of 60000, taken 0.83 sec per 1 batch
# 44160 img procesed out of 60000, taken 0.81 sec per 1 batch
# 45120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 46080 img procesed out of 60000, taken 0.79 sec per 1 batch
# 47040 img procesed out of 60000, taken 0.77 sec per 1 batch
# 48000 img procesed out of 60000, taken 1.05 sec per 1 batch
# 48960 img procesed out of 60000, taken 0.83 sec per 1 batch
# 49920 img procesed out of 60000, taken 0.79 sec per 1 batch
# 50880 img procesed out of 60000, taken 0.84 sec per 1 batch
# 51840 img procesed out of 60000, taken 0.80 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.79 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.81 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.80 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.80 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.81 sec per 1 batch
# End of epoch 3 / 110 	 Time Taken: 2384.82 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.81 sec per 1 batch
# 1440 img procesed out of 60000, taken 0.83 sec per 1 batch
# 2400 img procesed out of 60000, taken 0.81 sec per 1 batch
# 3360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 4320 img procesed out of 60000, taken 0.81 sec per 1 batch
# 5280 img procesed out of 60000, taken 0.76 sec per 1 batch
# 6240 img procesed out of 60000, taken 0.82 sec per 1 batch
# 7200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 8160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 9120 img procesed out of 60000, taken 0.79 sec per 1 batch
# 10080 img procesed out of 60000, taken 0.80 sec per 1 batch
# 11040 img procesed out of 60000, taken 0.78 sec per 1 batch
# 12000 img procesed out of 60000, taken 1.05 sec per 1 batch
# 12960 img procesed out of 60000, taken 0.81 sec per 1 batch
# 13920 img procesed out of 60000, taken 0.79 sec per 1 batch
# 14880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 15840 img procesed out of 60000, taken 0.81 sec per 1 batch
# 16800 img procesed out of 60000, taken 0.74 sec per 1 batch
# 17760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 18720 img procesed out of 60000, taken 0.77 sec per 1 batch
# 19680 img procesed out of 60000, taken 0.81 sec per 1 batch
# 20640 img procesed out of 60000, taken 0.80 sec per 1 batch
# 21600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 22560 img procesed out of 60000, taken 0.76 sec per 1 batch
# 23520 img procesed out of 60000, taken 0.81 sec per 1 batch
# 24480 img procesed out of 60000, taken 0.82 sec per 1 batch
# 25440 img procesed out of 60000, taken 0.82 sec per 1 batch
# 26400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 27360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 28320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 29280 img procesed out of 60000, taken 0.81 sec per 1 batch
# 30240 img procesed out of 60000, taken 0.75 sec per 1 batch
# 31200 img procesed out of 60000, taken 0.76 sec per 1 batch
# 32160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 33120 img procesed out of 60000, taken 0.77 sec per 1 batch
# 34080 img procesed out of 60000, taken 0.80 sec per 1 batch
# 35040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 36000 img procesed out of 60000, taken 1.07 sec per 1 batch
# 36960 img procesed out of 60000, taken 0.77 sec per 1 batch
# 37920 img procesed out of 60000, taken 0.76 sec per 1 batch
# 38880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 39840 img procesed out of 60000, taken 0.81 sec per 1 batch
# 40800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 41760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 42720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 43680 img procesed out of 60000, taken 0.79 sec per 1 batch
# 44640 img procesed out of 60000, taken 0.80 sec per 1 batch
# 45600 img procesed out of 60000, taken 0.83 sec per 1 batch
# 46560 img procesed out of 60000, taken 0.83 sec per 1 batch
# 47520 img procesed out of 60000, taken 0.82 sec per 1 batch
# 48480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 49440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 50400 img procesed out of 60000, taken 0.77 sec per 1 batch
# 51360 img procesed out of 60000, taken 0.78 sec per 1 batch
# 52320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 53280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 54240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 55200 img procesed out of 60000, taken 0.84 sec per 1 batch
# 56160 img procesed out of 60000, taken 0.82 sec per 1 batch
# 57120 img procesed out of 60000, taken 0.79 sec per 1 batch
# 58080 img procesed out of 60000, taken 0.82 sec per 1 batch
# 59040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 60000 img procesed out of 60000, taken 1.23 sec per 1 batch
# End of epoch 4 / 110 	 Time Taken: 2375.80 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 0.81 sec per 1 batch
# 1920 img procesed out of 60000, taken 0.80 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.80 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.75 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.82 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.80 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.81 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.80 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.77 sec per 1 batch
# 12480 img procesed out of 60000, taken 0.82 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.80 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.81 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.81 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.82 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.82 sec per 1 batch
# 20160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.80 sec per 1 batch
# 23040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.16 sec per 1 batch
# 24960 img procesed out of 60000, taken 0.82 sec per 1 batch
# 25920 img procesed out of 60000, taken 0.81 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.82 sec per 1 batch
# 27840 img procesed out of 60000, taken 0.81 sec per 1 batch
# 28800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.79 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 31680 img procesed out of 60000, taken 0.78 sec per 1 batch
# 32640 img procesed out of 60000, taken 0.81 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.80 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.81 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.81 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.81 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.81 sec per 1 batch
# 40320 img procesed out of 60000, taken 0.81 sec per 1 batch
# 41280 img procesed out of 60000, taken 0.78 sec per 1 batch
# 42240 img procesed out of 60000, taken 0.75 sec per 1 batch
# 43200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 44160 img procesed out of 60000, taken 0.78 sec per 1 batch
# 45120 img procesed out of 60000, taken 0.80 sec per 1 batch
# 46080 img procesed out of 60000, taken 0.79 sec per 1 batch
# 47040 img procesed out of 60000, taken 0.81 sec per 1 batch
# 48000 img procesed out of 60000, taken 1.06 sec per 1 batch
# 48960 img procesed out of 60000, taken 0.82 sec per 1 batch
# 49920 img procesed out of 60000, taken 0.81 sec per 1 batch
# 50880 img procesed out of 60000, taken 0.80 sec per 1 batch
# 51840 img procesed out of 60000, taken 0.82 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.83 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.78 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.82 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.83 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.81 sec per 1 batch
# saving the model at the end of epoch 5, iters 12500
# End of epoch 5 / 110 	 Time Taken: 2369.15 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.83 sec per 1 batch
# 1440 img procesed out of 60000, taken 0.82 sec per 1 batch
# 2400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 3360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 4320 img procesed out of 60000, taken 0.78 sec per 1 batch
# 5280 img procesed out of 60000, taken 0.77 sec per 1 batch
# 6240 img procesed out of 60000, taken 0.83 sec per 1 batch
# 7200 img procesed out of 60000, taken 0.82 sec per 1 batch
# 8160 img procesed out of 60000, taken 0.77 sec per 1 batch
# 9120 img procesed out of 60000, taken 0.80 sec per 1 batch
# 10080 img procesed out of 60000, taken 0.78 sec per 1 batch
# 11040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 12000 img procesed out of 60000, taken 1.15 sec per 1 batch
# 12960 img procesed out of 60000, taken 0.81 sec per 1 batch
# 13920 img procesed out of 60000, taken 0.75 sec per 1 batch
# 14880 img procesed out of 60000, taken 0.80 sec per 1 batch
# 15840 img procesed out of 60000, taken 0.79 sec per 1 batch
# 16800 img procesed out of 60000, taken 0.77 sec per 1 batch
# 17760 img procesed out of 60000, taken 0.81 sec per 1 batch
# 18720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 19680 img procesed out of 60000, taken 0.81 sec per 1 batch
# 20640 img procesed out of 60000, taken 0.81 sec per 1 batch
# 21600 img procesed out of 60000, taken 0.82 sec per 1 batch
# 22560 img procesed out of 60000, taken 0.80 sec per 1 batch
# 23520 img procesed out of 60000, taken 0.80 sec per 1 batch
# 24480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 25440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 26400 img procesed out of 60000, taken 0.82 sec per 1 batch
# 27360 img procesed out of 60000, taken 0.82 sec per 1 batch
# 28320 img procesed out of 60000, taken 0.76 sec per 1 batch
# 29280 img procesed out of 60000, taken 0.76 sec per 1 batch
# 30240 img procesed out of 60000, taken 0.76 sec per 1 batch
# 31200 img procesed out of 60000, taken 0.81 sec per 1 batch
# 32160 img procesed out of 60000, taken 0.81 sec per 1 batch
# 33120 img procesed out of 60000, taken 0.80 sec per 1 batch
# 34080 img procesed out of 60000, taken 0.79 sec per 1 batch
# 35040 img procesed out of 60000, taken 0.77 sec per 1 batch
# 36000 img procesed out of 60000, taken 1.16 sec per 1 batch
# 36960 img procesed out of 60000, taken 0.78 sec per 1 batch
# 37920 img procesed out of 60000, taken 0.82 sec per 1 batch
# 38880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 39840 img procesed out of 60000, taken 0.81 sec per 1 batch
# 40800 img procesed out of 60000, taken 0.82 sec per 1 batch
# 41760 img procesed out of 60000, taken 0.79 sec per 1 batch
# 42720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 43680 img procesed out of 60000, taken 0.76 sec per 1 batch
# 44640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 45600 img procesed out of 60000, taken 0.80 sec per 1 batch
# 46560 img procesed out of 60000, taken 0.81 sec per 1 batch
# 47520 img procesed out of 60000, taken 0.82 sec per 1 batch
# 48480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 49440 img procesed out of 60000, taken 0.83 sec per 1 batch
# 50400 img procesed out of 60000, taken 0.75 sec per 1 batch
# 51360 img procesed out of 60000, taken 0.81 sec per 1 batch
# 52320 img procesed out of 60000, taken 0.76 sec per 1 batch
# 53280 img procesed out of 60000, taken 0.79 sec per 1 batch
# 54240 img procesed out of 60000, taken 0.98 sec per 1 batch
# 55200 img procesed out of 60000, taken 0.79 sec per 1 batch
# 56160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 57120 img procesed out of 60000, taken 0.80 sec per 1 batch
# 58080 img procesed out of 60000, taken 0.80 sec per 1 batch
# 59040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 60000 img procesed out of 60000, taken 1.06 sec per 1 batch
# End of epoch 6 / 110 	 Time Taken: 2374.70 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 1920 img procesed out of 60000, taken 0.81 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.79 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.79 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.79 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.78 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.80 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.82 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.75 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.77 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.78 sec per 1 batch
# 12480 img procesed out of 60000, taken 0.83 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.82 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.81 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.81 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 20160 img procesed out of 60000, taken 0.83 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.81 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.79 sec per 1 batch
# 23040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.12 sec per 1 batch
# 24960 img procesed out of 60000, taken 0.81 sec per 1 batch
# 25920 img procesed out of 60000, taken 0.81 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 27840 img procesed out of 60000, taken 1.00 sec per 1 batch
# 28800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.75 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.80 sec per 1 batch
# 31680 img procesed out of 60000, taken 0.78 sec per 1 batch
# 32640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.83 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.78 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.78 sec per 1 batch
# 40320 img procesed out of 60000, taken 0.82 sec per 1 batch
# 41280 img procesed out of 60000, taken 0.81 sec per 1 batch
# 42240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 43200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 44160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 45120 img procesed out of 60000, taken 0.76 sec per 1 batch
# 46080 img procesed out of 60000, taken 0.79 sec per 1 batch
# 47040 img procesed out of 60000, taken 0.82 sec per 1 batch
# 48000 img procesed out of 60000, taken 1.14 sec per 1 batch
# 48960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 49920 img procesed out of 60000, taken 0.81 sec per 1 batch
# 50880 img procesed out of 60000, taken 0.82 sec per 1 batch
# 51840 img procesed out of 60000, taken 0.77 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.80 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.82 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.81 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.81 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.97 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.83 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.80 sec per 1 batch
# End of epoch 7 / 110 	 Time Taken: 2371.42 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.83 sec per 1 batch
# 1440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 2400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 3360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 4320 img procesed out of 60000, taken 0.98 sec per 1 batch
# 5280 img procesed out of 60000, taken 0.76 sec per 1 batch
# 6240 img procesed out of 60000, taken 0.81 sec per 1 batch
# 7200 img procesed out of 60000, taken 0.97 sec per 1 batch
# 8160 img procesed out of 60000, taken 0.83 sec per 1 batch
# 9120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 10080 img procesed out of 60000, taken 0.80 sec per 1 batch
# 11040 img procesed out of 60000, taken 0.82 sec per 1 batch
# 12000 img procesed out of 60000, taken 1.14 sec per 1 batch
# 12960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 13920 img procesed out of 60000, taken 0.81 sec per 1 batch
# 14880 img procesed out of 60000, taken 0.79 sec per 1 batch
# 15840 img procesed out of 60000, taken 0.81 sec per 1 batch
# 16800 img procesed out of 60000, taken 0.82 sec per 1 batch
# 17760 img procesed out of 60000, taken 0.79 sec per 1 batch
# 18720 img procesed out of 60000, taken 0.78 sec per 1 batch
# 19680 img procesed out of 60000, taken 0.75 sec per 1 batch
# 20640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 21600 img procesed out of 60000, taken 0.79 sec per 1 batch
# 22560 img procesed out of 60000, taken 0.80 sec per 1 batch
# 23520 img procesed out of 60000, taken 0.83 sec per 1 batch
# 24480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 25440 img procesed out of 60000, taken 0.80 sec per 1 batch
# 26400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 27360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 28320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 29280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 30240 img procesed out of 60000, taken 0.80 sec per 1 batch
# 31200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 32160 img procesed out of 60000, taken 0.79 sec per 1 batch
# 33120 img procesed out of 60000, taken 0.75 sec per 1 batch
# 34080 img procesed out of 60000, taken 0.76 sec per 1 batch
# 35040 img procesed out of 60000, taken 0.81 sec per 1 batch
# 36000 img procesed out of 60000, taken 1.07 sec per 1 batch
# 36960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 37920 img procesed out of 60000, taken 0.81 sec per 1 batch
# 38880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 39840 img procesed out of 60000, taken 0.81 sec per 1 batch
# 40800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 41760 img procesed out of 60000, taken 0.81 sec per 1 batch
# 42720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 43680 img procesed out of 60000, taken 0.80 sec per 1 batch
# 44640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 45600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 46560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 47520 img procesed out of 60000, taken 0.80 sec per 1 batch
# 48480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 49440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 50400 img procesed out of 60000, taken 0.76 sec per 1 batch
# 51360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 52320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 53280 img procesed out of 60000, taken 0.81 sec per 1 batch
# 54240 img procesed out of 60000, taken 0.75 sec per 1 batch
# 55200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 56160 img procesed out of 60000, taken 0.80 sec per 1 batch
# 57120 img procesed out of 60000, taken 0.80 sec per 1 batch
# 58080 img procesed out of 60000, taken 0.83 sec per 1 batch
# 59040 img procesed out of 60000, taken 0.77 sec per 1 batch
# 60000 img procesed out of 60000, taken 1.10 sec per 1 batch
# End of epoch 8 / 110 	 Time Taken: 2366.85 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 1920 img procesed out of 60000, taken 0.80 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.80 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.78 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.76 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.80 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.82 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.77 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.77 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.77 sec per 1 batch
# 12480 img procesed out of 60000, taken 1.06 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.81 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.82 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.77 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.81 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.75 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 20160 img procesed out of 60000, taken 0.81 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.80 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.81 sec per 1 batch
# 23040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.14 sec per 1 batch
# 24960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 25920 img procesed out of 60000, taken 0.83 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 27840 img procesed out of 60000, taken 0.80 sec per 1 batch
# 28800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 31680 img procesed out of 60000, taken 0.76 sec per 1 batch
# 32640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.82 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.80 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.81 sec per 1 batch
# 40320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 41280 img procesed out of 60000, taken 0.79 sec per 1 batch
# 42240 img procesed out of 60000, taken 0.80 sec per 1 batch
# 43200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 44160 img procesed out of 60000, taken 0.78 sec per 1 batch
# 45120 img procesed out of 60000, taken 0.80 sec per 1 batch
# 46080 img procesed out of 60000, taken 0.75 sec per 1 batch
# 47040 img procesed out of 60000, taken 0.81 sec per 1 batch
# 48000 img procesed out of 60000, taken 1.10 sec per 1 batch
# 48960 img procesed out of 60000, taken 0.75 sec per 1 batch
# 49920 img procesed out of 60000, taken 0.75 sec per 1 batch
# 50880 img procesed out of 60000, taken 0.81 sec per 1 batch
# 51840 img procesed out of 60000, taken 0.82 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.81 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.81 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.79 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.83 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.82 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.81 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.82 sec per 1 batch
# End of epoch 9 / 110 	 Time Taken: 2366.13 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 1440 img procesed out of 60000, taken 0.82 sec per 1 batch
# 2400 img procesed out of 60000, taken 0.82 sec per 1 batch
# 3360 img procesed out of 60000, taken 0.82 sec per 1 batch
# 4320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 5280 img procesed out of 60000, taken 0.81 sec per 1 batch
# 6240 img procesed out of 60000, taken 0.81 sec per 1 batch
# 7200 img procesed out of 60000, taken 0.81 sec per 1 batch
# 8160 img procesed out of 60000, taken 0.79 sec per 1 batch
# 9120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 10080 img procesed out of 60000, taken 0.78 sec per 1 batch
# 11040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 12000 img procesed out of 60000, taken 1.13 sec per 1 batch
# 12960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 13920 img procesed out of 60000, taken 0.77 sec per 1 batch
# 14880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 15840 img procesed out of 60000, taken 0.80 sec per 1 batch
# 16800 img procesed out of 60000, taken 0.81 sec per 1 batch
# 17760 img procesed out of 60000, taken 0.77 sec per 1 batch
# 18720 img procesed out of 60000, taken 0.75 sec per 1 batch
# 19680 img procesed out of 60000, taken 0.80 sec per 1 batch
# 20640 img procesed out of 60000, taken 0.80 sec per 1 batch
# 21600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 22560 img procesed out of 60000, taken 0.78 sec per 1 batch
# 23520 img procesed out of 60000, taken 0.79 sec per 1 batch
# 24480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 25440 img procesed out of 60000, taken 0.74 sec per 1 batch
# 26400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 27360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 28320 img procesed out of 60000, taken 0.81 sec per 1 batch
# 29280 img procesed out of 60000, taken 0.79 sec per 1 batch
# 30240 img procesed out of 60000, taken 0.80 sec per 1 batch
# 31200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 32160 img procesed out of 60000, taken 0.81 sec per 1 batch
# 33120 img procesed out of 60000, taken 0.82 sec per 1 batch
# 34080 img procesed out of 60000, taken 0.79 sec per 1 batch
# 35040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 36000 img procesed out of 60000, taken 1.09 sec per 1 batch
# 36960 img procesed out of 60000, taken 0.81 sec per 1 batch
# 37920 img procesed out of 60000, taken 0.80 sec per 1 batch
# 38880 img procesed out of 60000, taken 0.76 sec per 1 batch
# 39840 img procesed out of 60000, taken 0.77 sec per 1 batch
# 40800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 41760 img procesed out of 60000, taken 0.80 sec per 1 batch
# 42720 img procesed out of 60000, taken 0.76 sec per 1 batch
# 43680 img procesed out of 60000, taken 0.77 sec per 1 batch
# 44640 img procesed out of 60000, taken 0.74 sec per 1 batch
# 45600 img procesed out of 60000, taken 0.79 sec per 1 batch
# 46560 img procesed out of 60000, taken 0.78 sec per 1 batch
# 47520 img procesed out of 60000, taken 0.80 sec per 1 batch
# 48480 img procesed out of 60000, taken 0.81 sec per 1 batch
# 49440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 50400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 51360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 52320 img procesed out of 60000, taken 0.78 sec per 1 batch
# 53280 img procesed out of 60000, taken 0.77 sec per 1 batch
# 54240 img procesed out of 60000, taken 0.81 sec per 1 batch
# 55200 img procesed out of 60000, taken 0.77 sec per 1 batch
# 56160 img procesed out of 60000, taken 0.81 sec per 1 batch
# 57120 img procesed out of 60000, taken 0.81 sec per 1 batch
# 58080 img procesed out of 60000, taken 0.83 sec per 1 batch
# 59040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 60000 img procesed out of 60000, taken 1.16 sec per 1 batch
# saving the model at the end of epoch 10, iters 25000
# End of epoch 10 / 110 	 Time Taken: 2351.30 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 0.76 sec per 1 batch
# 1920 img procesed out of 60000, taken 0.79 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.77 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.79 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.76 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.81 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.81 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.81 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.81 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.77 sec per 1 batch
# 12480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.99 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.82 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.81 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.77 sec per 1 batch
# 20160 img procesed out of 60000, taken 0.81 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.82 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.78 sec per 1 batch
# 23040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.10 sec per 1 batch
# 24960 img procesed out of 60000, taken 0.80 sec per 1 batch
# 25920 img procesed out of 60000, taken 0.77 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.80 sec per 1 batch
# 27840 img procesed out of 60000, taken 0.80 sec per 1 batch
# 28800 img procesed out of 60000, taken 0.79 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.80 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.78 sec per 1 batch
# 31680 img procesed out of 60000, taken 0.79 sec per 1 batch
# 32640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.80 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.82 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.78 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.80 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.81 sec per 1 batch
# ...
# 51840 img procesed out of 60000, taken 0.77 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.78 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.77 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.77 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.77 sec per 1 batch
# saving the model at the end of epoch 35, iters 87500
# End of epoch 35 / 110 	 Time Taken: 2300.16 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.78 sec per 1 batch
# 1440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 2400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 3360 img procesed out of 60000, taken 0.77 sec per 1 batch
# 4320 img procesed out of 60000, taken 0.78 sec per 1 batch
# 5280 img procesed out of 60000, taken 0.79 sec per 1 batch
# 6240 img procesed out of 60000, taken 0.77 sec per 1 batch
# 7200 img procesed out of 60000, taken 0.77 sec per 1 batch
# 8160 img procesed out of 60000, taken 0.78 sec per 1 batch
# 9120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 10080 img procesed out of 60000, taken 0.77 sec per 1 batch
# 11040 img procesed out of 60000, taken 0.90 sec per 1 batch
# 12000 img procesed out of 60000, taken 1.11 sec per 1 batch
# 12960 img procesed out of 60000, taken 0.77 sec per 1 batch
# 13920 img procesed out of 60000, taken 0.79 sec per 1 batch
# 14880 img procesed out of 60000, taken 0.80 sec per 1 batch
# 15840 img procesed out of 60000, taken 0.79 sec per 1 batch
# 16800 img procesed out of 60000, taken 0.77 sec per 1 batch
# 17760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 18720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 19680 img procesed out of 60000, taken 0.78 sec per 1 batch
# 20640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 21600 img procesed out of 60000, taken 0.79 sec per 1 batch
# 22560 img procesed out of 60000, taken 0.77 sec per 1 batch
# 23520 img procesed out of 60000, taken 0.78 sec per 1 batch
# 24480 img procesed out of 60000, taken 0.79 sec per 1 batch
# 25440 img procesed out of 60000, taken 0.77 sec per 1 batch
# 26400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 27360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 28320 img procesed out of 60000, taken 0.78 sec per 1 batch
# 29280 img procesed out of 60000, taken 0.78 sec per 1 batch
# 30240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 31200 img procesed out of 60000, taken 0.77 sec per 1 batch
# 32160 img procesed out of 60000, taken 0.77 sec per 1 batch
# 33120 img procesed out of 60000, taken 0.79 sec per 1 batch
# 34080 img procesed out of 60000, taken 0.77 sec per 1 batch
# 35040 img procesed out of 60000, taken 0.77 sec per 1 batch
# 36000 img procesed out of 60000, taken 1.09 sec per 1 batch
# 36960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 37920 img procesed out of 60000, taken 0.77 sec per 1 batch
# 38880 img procesed out of 60000, taken 0.77 sec per 1 batch
# 39840 img procesed out of 60000, taken 0.77 sec per 1 batch
# 40800 img procesed out of 60000, taken 0.77 sec per 1 batch
# 41760 img procesed out of 60000, taken 0.77 sec per 1 batch
# 42720 img procesed out of 60000, taken 0.77 sec per 1 batch
# 43680 img procesed out of 60000, taken 0.76 sec per 1 batch
# 44640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 45600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 46560 img procesed out of 60000, taken 0.81 sec per 1 batch
# 47520 img procesed out of 60000, taken 0.80 sec per 1 batch
# 48480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 49440 img procesed out of 60000, taken 0.77 sec per 1 batch
# 50400 img procesed out of 60000, taken 0.78 sec per 1 batch
# 51360 img procesed out of 60000, taken 0.78 sec per 1 batch
# 52320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 53280 img procesed out of 60000, taken 0.79 sec per 1 batch
# 54240 img procesed out of 60000, taken 0.77 sec per 1 batch
# 55200 img procesed out of 60000, taken 0.79 sec per 1 batch
# 56160 img procesed out of 60000, taken 0.79 sec per 1 batch
# 57120 img procesed out of 60000, taken 0.87 sec per 1 batch
# 58080 img procesed out of 60000, taken 0.78 sec per 1 batch
# 59040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 60000 img procesed out of 60000, taken 1.10 sec per 1 batch
# End of epoch 36 / 110 	 Time Taken: 2301.41 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 1920 img procesed out of 60000, taken 0.78 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.78 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.80 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.79 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.80 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.77 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.79 sec per 1 batch
# 12480 img procesed out of 60000, taken 0.77 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.78 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.77 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.77 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 20160 img procesed out of 60000, taken 0.77 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.79 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.78 sec per 1 batch
# 23040 img procesed out of 60000, taken 0.78 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.09 sec per 1 batch
# 24960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 25920 img procesed out of 60000, taken 0.78 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.80 sec per 1 batch
# 27840 img procesed out of 60000, taken 0.77 sec per 1 batch
# 28800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.79 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.77 sec per 1 batch
# 31680 img procesed out of 60000, taken 0.77 sec per 1 batch
# 32640 img procesed out of 60000, taken 0.77 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.80 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.78 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.77 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.79 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.78 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.79 sec per 1 batch
# 40320 img procesed out of 60000, taken 0.76 sec per 1 batch
# 41280 img procesed out of 60000, taken 0.78 sec per 1 batch
# 42240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 43200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 44160 img procesed out of 60000, taken 0.77 sec per 1 batch
# 45120 img procesed out of 60000, taken 0.77 sec per 1 batch
# 46080 img procesed out of 60000, taken 0.77 sec per 1 batch
# 47040 img procesed out of 60000, taken 0.80 sec per 1 batch
# 48000 img procesed out of 60000, taken 1.12 sec per 1 batch
# 48960 img procesed out of 60000, taken 0.77 sec per 1 batch
# 49920 img procesed out of 60000, taken 0.78 sec per 1 batch
# 50880 img procesed out of 60000, taken 0.77 sec per 1 batch
# 51840 img procesed out of 60000, taken 0.78 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.76 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.77 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.78 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.77 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.77 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.78 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.80 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.78 sec per 1 batch
# End of epoch 37 / 110 	 Time Taken: 2301.60 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.78 sec per 1 batch
# 1440 img procesed out of 60000, taken 0.76 sec per 1 batch
# 2400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 3360 img procesed out of 60000, taken 0.78 sec per 1 batch
# 4320 img procesed out of 60000, taken 0.79 sec per 1 batch
# 5280 img procesed out of 60000, taken 0.78 sec per 1 batch
# 6240 img procesed out of 60000, taken 0.77 sec per 1 batch
# 7200 img procesed out of 60000, taken 0.79 sec per 1 batch
# 8160 img procesed out of 60000, taken 0.79 sec per 1 batch
# 9120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 10080 img procesed out of 60000, taken 0.80 sec per 1 batch
# 11040 img procesed out of 60000, taken 0.77 sec per 1 batch
# 12000 img procesed out of 60000, taken 1.11 sec per 1 batch
# 12960 img procesed out of 60000, taken 0.77 sec per 1 batch
# 13920 img procesed out of 60000, taken 0.78 sec per 1 batch
# 14880 img procesed out of 60000, taken 0.76 sec per 1 batch
# 15840 img procesed out of 60000, taken 0.78 sec per 1 batch
# 16800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 17760 img procesed out of 60000, taken 0.80 sec per 1 batch
# 18720 img procesed out of 60000, taken 0.77 sec per 1 batch
# 19680 img procesed out of 60000, taken 0.79 sec per 1 batch
# 20640 img procesed out of 60000, taken 0.79 sec per 1 batch
# 21600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 22560 img procesed out of 60000, taken 0.77 sec per 1 batch
# 23520 img procesed out of 60000, taken 0.77 sec per 1 batch
# 24480 img procesed out of 60000, taken 0.76 sec per 1 batch
# 25440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 26400 img procesed out of 60000, taken 0.79 sec per 1 batch
# 27360 img procesed out of 60000, taken 0.77 sec per 1 batch
# 28320 img procesed out of 60000, taken 0.77 sec per 1 batch
# 29280 img procesed out of 60000, taken 0.77 sec per 1 batch
# 30240 img procesed out of 60000, taken 0.77 sec per 1 batch
# 31200 img procesed out of 60000, taken 0.80 sec per 1 batch
# 32160 img procesed out of 60000, taken 0.79 sec per 1 batch
# 33120 img procesed out of 60000, taken 0.77 sec per 1 batch
# 34080 img procesed out of 60000, taken 0.77 sec per 1 batch
# 35040 img procesed out of 60000, taken 0.76 sec per 1 batch
# 36000 img procesed out of 60000, taken 1.08 sec per 1 batch
# 36960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 37920 img procesed out of 60000, taken 0.79 sec per 1 batch
# 38880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 39840 img procesed out of 60000, taken 0.78 sec per 1 batch
# 40800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 41760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 42720 img procesed out of 60000, taken 0.79 sec per 1 batch
# 43680 img procesed out of 60000, taken 0.78 sec per 1 batch
# 44640 img procesed out of 60000, taken 0.77 sec per 1 batch
# 45600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 46560 img procesed out of 60000, taken 0.78 sec per 1 batch
# 47520 img procesed out of 60000, taken 0.77 sec per 1 batch
# 48480 img procesed out of 60000, taken 0.76 sec per 1 batch
# 49440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 50400 img procesed out of 60000, taken 0.77 sec per 1 batch
# 51360 img procesed out of 60000, taken 0.77 sec per 1 batch
# 52320 img procesed out of 60000, taken 0.76 sec per 1 batch
# 53280 img procesed out of 60000, taken 0.81 sec per 1 batch
# 54240 img procesed out of 60000, taken 0.78 sec per 1 batch
# 55200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 56160 img procesed out of 60000, taken 0.78 sec per 1 batch
# 57120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 58080 img procesed out of 60000, taken 0.78 sec per 1 batch
# 59040 img procesed out of 60000, taken 0.78 sec per 1 batch
# 60000 img procesed out of 60000, taken 1.07 sec per 1 batch
# End of epoch 38 / 110 	 Time Taken: 2298.34 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 0.78 sec per 1 batch
# 1920 img procesed out of 60000, taken 0.79 sec per 1 batch
# 2880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 3840 img procesed out of 60000, taken 0.79 sec per 1 batch
# 4800 img procesed out of 60000, taken 0.80 sec per 1 batch
# 5760 img procesed out of 60000, taken 0.79 sec per 1 batch
# 6720 img procesed out of 60000, taken 0.78 sec per 1 batch
# 7680 img procesed out of 60000, taken 0.78 sec per 1 batch
# 8640 img procesed out of 60000, taken 0.76 sec per 1 batch
# 9600 img procesed out of 60000, taken 0.79 sec per 1 batch
# 10560 img procesed out of 60000, taken 0.79 sec per 1 batch
# 11520 img procesed out of 60000, taken 0.77 sec per 1 batch
# 12480 img procesed out of 60000, taken 0.77 sec per 1 batch
# 13440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 14400 img procesed out of 60000, taken 0.76 sec per 1 batch
# 15360 img procesed out of 60000, taken 0.76 sec per 1 batch
# 16320 img procesed out of 60000, taken 0.78 sec per 1 batch
# 17280 img procesed out of 60000, taken 0.79 sec per 1 batch
# 18240 img procesed out of 60000, taken 0.79 sec per 1 batch
# 19200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 20160 img procesed out of 60000, taken 0.77 sec per 1 batch
# 21120 img procesed out of 60000, taken 0.77 sec per 1 batch
# 22080 img procesed out of 60000, taken 0.77 sec per 1 batch
# 23040 img procesed out of 60000, taken 0.79 sec per 1 batch
# 24000 img procesed out of 60000, taken 1.09 sec per 1 batch
# 24960 img procesed out of 60000, taken 0.79 sec per 1 batch
# 25920 img procesed out of 60000, taken 0.80 sec per 1 batch
# 26880 img procesed out of 60000, taken 0.76 sec per 1 batch
# 27840 img procesed out of 60000, taken 0.78 sec per 1 batch
# 28800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 29760 img procesed out of 60000, taken 0.78 sec per 1 batch
# 30720 img procesed out of 60000, taken 0.80 sec per 1 batch
# 31680 img procesed out of 60000, taken 0.79 sec per 1 batch
# 32640 img procesed out of 60000, taken 0.78 sec per 1 batch
# 33600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 34560 img procesed out of 60000, taken 0.76 sec per 1 batch
# 35520 img procesed out of 60000, taken 0.77 sec per 1 batch
# 36480 img procesed out of 60000, taken 0.80 sec per 1 batch
# 37440 img procesed out of 60000, taken 0.78 sec per 1 batch
# 38400 img procesed out of 60000, taken 0.77 sec per 1 batch
# 39360 img procesed out of 60000, taken 0.80 sec per 1 batch
# 40320 img procesed out of 60000, taken 0.80 sec per 1 batch
# 41280 img procesed out of 60000, taken 0.80 sec per 1 batch
# 42240 img procesed out of 60000, taken 0.78 sec per 1 batch
# 43200 img procesed out of 60000, taken 0.78 sec per 1 batch
# 44160 img procesed out of 60000, taken 0.78 sec per 1 batch
# 45120 img procesed out of 60000, taken 0.78 sec per 1 batch
# 46080 img procesed out of 60000, taken 0.77 sec per 1 batch
# 47040 img procesed out of 60000, taken 0.78 sec per 1 batch
# 48000 img procesed out of 60000, taken 1.09 sec per 1 batch
# 48960 img procesed out of 60000, taken 0.77 sec per 1 batch
# 49920 img procesed out of 60000, taken 0.78 sec per 1 batch
# 50880 img procesed out of 60000, taken 0.78 sec per 1 batch
# 51840 img procesed out of 60000, taken 0.77 sec per 1 batch
# 52800 img procesed out of 60000, taken 0.78 sec per 1 batch
# 53760 img procesed out of 60000, taken 0.77 sec per 1 batch
# 54720 img procesed out of 60000, taken 0.77 sec per 1 batch
# 55680 img procesed out of 60000, taken 0.78 sec per 1 batch
# 56640 img procesed out of 60000, taken 0.77 sec per 1 batch
# 57600 img procesed out of 60000, taken 0.77 sec per 1 batch
# 58560 img procesed out of 60000, taken 0.78 sec per 1 batch
# 59520 img procesed out of 60000, taken 0.77 sec per 1 batch
# End of epoch 39 / 110 	 Time Taken: 2300.00 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 0.79 sec per 1 batch

# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/Scannet_cleaned \
--name scannet_unflow_unpaired \
--gpu_ids 0,1,2,3\
--batch_size 48\
--model unflow_gan\
--crop_size_h 128\
--crop_size_w 128\
--load_size_h 192\
--load_size_w 192\
--num_iter_gen 3\
--disc_for_normals\
--disc_for_depth\
--use_spnorm\
--use_cycle_B\
--l_depth_A_begin 0\
--l_depth_A_end 0\
--l_depth_B_begin 1\
--l_depth_B_end 1\
--l_cycle_A_begin 10.\
--l_cycle_A_end 10.\
--l_cycle_B_begin 10.\
--l_cycle_B_end 10.\
--l_identity 5.0\
--l_normal 20.\
--data_shuffle\
--max_dataset_size 60000\
--init_type  normal\
--lr_D 0.0002\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 5\
--n_epochs 100\
--n_epochs_decay 5\
--norm_d none \
--inp_B img_depth
# Out:
# ----------------- Options ---------------
#                batch_size: 48                            	[default: 8]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#               crop_size_h: 128                           	[default: 240]
#               crop_size_w: 128                           	[default: 320]
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/Scannet_cleaned	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#                     debug: False
#             deterministic: False
#            disc_for_depth: True                          	[default: False]
#          disc_for_normals: True                          	[default: False]
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0,1,2,3                       	[default: 1,2]
#               hole_border: -0.97
#             img2depth_dir: ./checkpoints/img2d_pretrain/
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal                        	[default: xavier]
#                     inp_B: img_depth                     	[default: depth]
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0
#             l_cycle_A_end: 10.0
#           l_cycle_B_begin: 10.0
#             l_cycle_B_end: 10.0
#           l_depth_A_begin: 0.0                           	[default: 5.0]
#             l_depth_A_end: 0.0
#           l_depth_B_begin: 1.0                           	[default: 5.0]
#             l_depth_B_end: 1.0                           	[default: 0.0]
#                  l_hole_A: 0.0
#                l_identity: 5.0                           	[default: 0.0]
#                l_max_iter: 5000
#                  l_mean_A: 0.0
#                  l_mean_B: 0.0
#                  l_normal: 20.0                          	[default: 10.0]
#                l_num_iter: 5000
# l_reconstruction_semantic: 0.0
#                    l_tv_A: 0.0
#                load_epoch: last
#      load_epoch_img2depth: last
#        load_epoch_weights: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 192                           	[default: 480]
#               load_size_w: 192                           	[default: 640]
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 60000                         	[default: inf]
#              max_distance: 8000.0
#                     model: unflow_gan                    	[default: semi_cycle_gan]
#                  n_blocks: 9
#            n_downsampling: 2
#                  n_epochs: 100                           	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: scannet_unflow_unpaired       	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32
#                   ngf_img: 32
#           ngf_img_feature: 32
#                      norm: group
#                    norm_d: none                          	[default: instance]
#              num_iter_dis: 1
#              num_iter_gen: 3                             	[default: 1]
#               num_workers: 4
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 5                             	[default: 10]
#           upsampling_type: transpose
#               use_cycle_A: False
#               use_cycle_B: True                          	[default: False]
#         use_mean_matching: False
#    use_pretrain_img2depth: False
#      use_pretrain_weights: False
#              use_semantic: False
#      use_semi_cycle_first: False
#     use_semi_cycle_second: False
#                use_spnorm: True                          	[default: False]
#                   verbose: False
#                 w_decay_G: 0.0001
#               weights_dir: ./checkpoints/pretrain_weights_imgdepht/
# ----------------- End -------------------
# wandb: Currently logged in as: blaabl (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.11
# wandb: Syncing run scannet_unflow_unpaired
# wandb: ⭐️ View project at https://wandb.ai/blaabl/un_depth
# wandb: 🚀 View run at https://wandb.ai/blaabl/un_depth/runs/3c9dejxs
# wandb: Run data is saved locally in /workspace/code/my_cyclegan/wandb/run-20201213_190120-3c9dejxs
# wandb: Run `wandb offline` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 60000
# Dataset SemiCycleDataset was created
# The number of test images = 46567
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [UnFlowGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.620 M
# [Network netG_B] Total number of parameters : 11.620 M
# [Network netD_A_depth] Total number of parameters : 2.762 M
# [Network netD_B_depth] Total number of parameters : 2.762 M
# [Network netD_A_normal] Total number of parameters : 2.764 M
# [Network netD_B_normal] Total number of parameters : 2.764 M
# -----------------------------------------------
# 1920 img procesed out of 60000, taken 2.25 sec per 1 batch
# 3840 img procesed out of 60000, taken 2.31 sec per 1 batch
# 5760 img procesed out of 60000, taken 2.41 sec per 1 batch
# 7680 img procesed out of 60000, taken 2.29 sec per 1 batch
# 9600 img procesed out of 60000, taken 2.36 sec per 1 batch
# 11520 img procesed out of 60000, taken 2.29 sec per 1 batch
# 13440 img procesed out of 60000, taken 2.32 sec per 1 batch
# 15360 img procesed out of 60000, taken 2.32 sec per 1 batch
# 17280 img procesed out of 60000, taken 2.31 sec per 1 batch
# 19200 img procesed out of 60000, taken 2.30 sec per 1 batch
# 21120 img procesed out of 60000, taken 2.29 sec per 1 batch
# 23040 img procesed out of 60000, taken 2.28 sec per 1 batch
# 24960 img procesed out of 60000, taken 2.29 sec per 1 batch
# 26880 img procesed out of 60000, taken 2.44 sec per 1 batch
# 28800 img procesed out of 60000, taken 2.30 sec per 1 batch
# 30720 img procesed out of 60000, taken 2.29 sec per 1 batch
# 32640 img procesed out of 60000, taken 2.29 sec per 1 batch
# 34560 img procesed out of 60000, taken 2.32 sec per 1 batch
# 36480 img procesed out of 60000, taken 2.30 sec per 1 batch
# 38400 img procesed out of 60000, taken 2.33 sec per 1 batch
# 40320 img procesed out of 60000, taken 2.32 sec per 1 batch
# 42240 img procesed out of 60000, taken 2.32 sec per 1 batch
# 44160 img procesed out of 60000, taken 2.34 sec per 1 batch
# 46080 img procesed out of 60000, taken 2.32 sec per 1 batch
# 48000 img procesed out of 60000, taken 2.59 sec per 1 batch
# 49920 img procesed out of 60000, taken 2.31 sec per 1 batch
# 51840 img procesed out of 60000, taken 2.28 sec per 1 batch
# 53760 img procesed out of 60000, taken 2.31 sec per 1 batch
# 55680 img procesed out of 60000, taken 2.31 sec per 1 batch
# 57600 img procesed out of 60000, taken 2.34 sec per 1 batch
# 59520 img procesed out of 60000, taken 2.30 sec per 1 batch
# End of epoch 1 / 105 	 Time Taken: 3080.22 sec
# learning rate = 0.0002000
# 1440 img procesed out of 60000, taken 2.34 sec per 1 batch
# 3360 img procesed out of 60000, taken 2.34 sec per 1 batch
# 5280 img procesed out of 60000, taken 2.32 sec per 1 batch
# 7200 img procesed out of 60000, taken 2.28 sec per 1 batch
# 9120 img procesed out of 60000, taken 2.29 sec per 1 batch
# 11040 img procesed out of 60000, taken 2.30 sec per 1 batch
# 12960 img procesed out of 60000, taken 2.29 sec per 1 batch
# 14880 img procesed out of 60000, taken 2.29 sec per 1 batch
# 16800 img procesed out of 60000, taken 2.40 sec per 1 batch
# 18720 img procesed out of 60000, taken 2.31 sec per 1 batch
# 20640 img procesed out of 60000, taken 2.32 sec per 1 batch
# 22560 img procesed out of 60000, taken 2.30 sec per 1 batch
# 24480 img procesed out of 60000, taken 2.35 sec per 1 batch
# 26400 img procesed out of 60000, taken 2.29 sec per 1 batch
# 28320 img procesed out of 60000, taken 2.35 sec per 1 batch
# 30240 img procesed out of 60000, taken 2.30 sec per 1 batch
# 32160 img procesed out of 60000, taken 2.31 sec per 1 batch
# 34080 img procesed out of 60000, taken 2.30 sec per 1 batch
# 36000 img procesed out of 60000, taken 2.55 sec per 1 batch
# 37920 img procesed out of 60000, taken 2.33 sec per 1 batch
# 39840 img procesed out of 60000, taken 2.32 sec per 1 batch
# 41760 img procesed out of 60000, taken 2.30 sec per 1 batch
# 43680 img procesed out of 60000, taken 2.29 sec per 1 batch
# 45600 img procesed out of 60000, taken 2.29 sec per 1 batch
# 47520 img procesed out of 60000, taken 2.30 sec per 1 batch
# 49440 img procesed out of 60000, taken 2.28 sec per 1 batch
# 51360 img procesed out of 60000, taken 2.36 sec per 1 batch
# 53280 img procesed out of 60000, taken 2.39 sec per 1 batch
# 55200 img procesed out of 60000, taken 2.28 sec per 1 batch
# 57120 img procesed out of 60000, taken 2.33 sec per 1 batch
# 59040 img procesed out of 60000, taken 2.42 sec per 1 batch
# End of epoch 2 / 105 	 Time Taken: 3081.41 sec
# learning rate = 0.0002000
# 960 img procesed out of 60000, taken 2.31 sec per 1 batch
# 2880 img procesed out of 60000, taken 2.32 sec per 1 batch
# 4800 img procesed out of 60000, taken 2.29 sec per 1 batch
# 6720 img procesed out of 60000, taken 2.27 sec per 1 batch
# 8640 img procesed out of 60000, taken 2.29 sec per 1 batch
# 10560 img procesed out of 60000, taken 2.30 sec per 1 batch
# 12480 img procesed out of 60000, taken 2.31 sec per 1 batch
# 14400 img procesed out of 60000, taken 2.30 sec per 1 batch
# 16320 img procesed out of 60000, taken 2.31 sec per 1 batch
# 18240 img procesed out of 60000, taken 2.30 sec per 1 batch
# 20160 img procesed out of 60000, taken 2.30 sec per 1 batch
# 22080 img procesed out of 60000, taken 2.30 sec per 1 batch
# 24000 img procesed out of 60000, taken 2.61 sec per 1 batch
# 25920 img procesed out of 60000, taken 2.29 sec per 1 batch
# 27840 img procesed out of 60000, taken 2.29 sec per 1 batch
# 29760 img procesed out of 60000, taken 2.30 sec per 1 batch
# 31680 img procesed out of 60000, taken 2.35 sec per 1 batch
# 33600 img procesed out of 60000, taken 2.33 sec per 1 batch
# 35520 img procesed out of 60000, taken 2.34 sec per 1 batch
# 37440 img procesed out of 60000, taken 2.31 sec per 1 batch
# 39360 img procesed out of 60000, taken 2.40 sec per 1 batch
# 41280 img procesed out of 60000, taken 2.35 sec per 1 batch
# 43200 img procesed out of 60000, taken 2.33 sec per 1 batch
# 45120 img procesed out of 60000, taken 2.33 sec per 1 batch
# 47040 img procesed out of 60000, taken 2.36 sec per 1 batch
# 48960 img procesed out of 60000, taken 2.31 sec per 1 batch
# 50880 img procesed out of 60000, taken 2.29 sec per 1 batch
# 52800 img procesed out of 60000, taken 2.30 sec per 1 batch
# 54720 img procesed out of 60000, taken 2.27 sec per 1 batch
# 56640 img procesed out of 60000, taken 2.32 sec per 1 batch
# 58560 img procesed out of 60000, taken 2.31 sec per 1 batch
# End of epoch 3 / 105 	 Time Taken: 3081.73 sec
# learning rate = 0.0002000
# 480 img procesed out of 60000, taken 2.27 sec per 1 batch
# 2400 img procesed out of 60000, taken 2.42 sec per 1 batch
# 4320 img procesed out of 60000, taken 2.33 sec per 1 batch
