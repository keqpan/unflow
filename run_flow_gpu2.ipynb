# %%
import os
os.chdir('/workspace/code/my_cyclegan')

# %%
# !ls
# Out:
# redwood  testA	testB  trainA  trainB  valA  valB

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"

# %%
# !CUDA_DEVICE_ORDER="PCI_BUS_ID" python train.py --dataroot /data/unpaired_depth/sample/ \
--gpu_ids 0,1,2,3 \
--upsampling_type transpose\
--use_second_cycle\
--name BA_lsgan \
--gan_mode lsgan\
--init_type xavier\
--n_blocks 6\
--ngf_depth 32\
--ngf_img 32\
--num_iter_gen 1\
--l_depth_A_begin 70\
--l_depth_A_end 70\
--l_depth_B_begin 10\
--l_depth_B_end 10\
--l_depth_max_iter 30000\
--l_cycle_A_begin 5.0\
--l_cycle_A_end 5.0\
--l_identity 2.5\
--max_dataset_size 20000\
--data_shuffle\
--batch_size 16\
--lr_D 0.0003\
--lr_G 0.0002\
--img_freq 40\
--loss_freq 30\
--save_epoch_freq 1\
--n_epochs 100\
--n_epochs_decay 5
# Out:
# ----------------- Options ---------------
#                batch_size: 16                            	[default: 5]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#              data_shuffle: True                          	[default: False]
#                  dataroot: /data/unpaired_depth/sample/  	[default: /all_data/hdd/un_depth/semi/sample]
#              dataset_mode: semi_cycle
#             deterministic: False
#          disc_for_normals: False
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0,1,2,3                       	[default: 0,1]
#                  img_freq: 40                            	[default: 1]
#                 init_type: xavier
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 5.0                           	[default: 10.0]
#             l_cycle_A_end: 5.0                           	[default: 10.0]
#           l_cycle_B_begin: 10.0
#             l_cycle_B_end: 10.0
#           l_depth_A_begin: 70.0                          	[default: 5.0]
#             l_depth_A_end: 70.0                          	[default: 0.0]
#           l_depth_B_begin: 10.0                          	[default: 5.0]
#             l_depth_B_end: 10.0                          	[default: 0.0]
#          l_depth_max_iter: 30000                         	[default: 5000]
#                l_identity: 2.5                           	[default: 0.0]
# l_reconstruction_semantic: 0.0
#                load_epoch: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 480
#               load_size_w: 640
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0003                        	[default: 0.0002]
#                      lr_G: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 20000                         	[default: inf]
#              max_distance: 8000.0
#                     model: semi_cycle_gan
#                  n_blocks: 6                             	[default: 9]
#            n_downsampling: 2
#                  n_epochs: 100                           	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: BA_lsgan                      	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32
#                   ngf_img: 32
#                      norm: instance
#              num_iter_dis: 1
#              num_iter_gen: 1
#               num_workers: 4
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 1                             	[default: 10]
#           upsampling_type: transpose                     	[default: upconv]
#                  use_blur: False
#         use_mean_matching: False
#          use_second_cycle: True                          	[default: False]
#              use_semantic: False
#                   verbose: False
# ----------------- End -------------------
# wandb: Currently logged in as: blaabl (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.11
# wandb: Syncing run BA_lsgan
# wandb: ⭐️ View project at https://wandb.ai/blaabl/un_depth
# wandb: 🚀 View run at https://wandb.ai/blaabl/un_depth/runs/3plhka7l
# wandb: Run data is saved locally in /workspace/code/my_cyclegan/wandb/run-20201124_192940-3plhka7l
# wandb: Run `wandb offline` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 20000
# GPU_IDS: [0, 1, 2, 3]
# initialize network with xavier
# GPU_IDS: [0, 1, 2, 3]
# initialize network with xavier
# GPU_IDS: [0, 1, 2, 3]
# initialize network with xavier
# GPU_IDS: [0, 1, 2, 3]
# initialize network with xavier
# model [SemiCycleGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 8.074 M
# [Network netG_B] Total number of parameters : 8.399 M
# [Network netD_A_depth] Total number of parameters : 2.763 M
# [Network netD_B_depth] Total number of parameters : 2.763 M
# -----------------------------------------------
# D_A loss : 0.220, D_B loss : 0.486
# 640 img procesed out of 20000, taken 0.95 sec per 1 batch
# D_A loss : 0.148, D_B loss : 0.180
# 1280 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.160, D_B loss : 0.205
# 1920 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.156, D_B loss : 0.146
# 2560 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.150, D_B loss : 0.586
# 3200 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.079, D_B loss : 0.213
# 3840 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.113, D_B loss : 0.123
# 4480 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.088, D_B loss : 0.116
# 5120 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.088, D_B loss : 0.104
# 5760 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.095, D_B loss : 0.147
# 6400 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.089, D_B loss : 0.107
# 7040 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.110, D_B loss : 0.114
# 7680 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.100, D_B loss : 0.054
# 8320 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.254, D_B loss : 0.101
# 8960 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.067, D_B loss : 0.129
# 9600 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.209, D_B loss : 0.119
# 10240 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.065, D_B loss : 0.085
# 10880 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.180, D_B loss : 0.157
# 11520 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.123, D_B loss : 0.185
# 12160 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.075, D_B loss : 0.119
# 12800 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.111, D_B loss : 0.103
# 13440 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.100, D_B loss : 0.061
# 14080 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.057, D_B loss : 0.453
# 14720 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.045, D_B loss : 0.060
# 15360 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.087, D_B loss : 0.203
# 16000 img procesed out of 20000, taken 1.18 sec per 1 batch
# D_A loss : 0.060, D_B loss : 0.122
# 16640 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.071, D_B loss : 0.669
# 17280 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.024, D_B loss : 0.098
# 17920 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.043, D_B loss : 0.176
# 18560 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.035, D_B loss : 0.086
# 19200 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.076, D_B loss : 0.084
# 19840 img procesed out of 20000, taken 0.97 sec per 1 batch
# saving the model at the end of epoch 1, iters 1250
# End of epoch 1 / 105 	 Time Taken: 1392.87 sec
# learning rate = 0.0002000
# D_A loss : 0.039, D_B loss : 0.062
# 480 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.061, D_B loss : 0.118
# 1120 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 1.091, D_B loss : 0.124
# 1760 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.094, D_B loss : 0.263
# 2400 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.065, D_B loss : 0.019
# 3040 img procesed out of 20000, taken 0.96 sec per 1 batch
# D_A loss : 0.108, D_B loss : 0.061
# 3680 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.092, D_B loss : 0.107
# 4320 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.137, D_B loss : 0.046
# 4960 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.045, D_B loss : 0.158
# 5600 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.035, D_B loss : 0.044
# 6240 img procesed out of 20000, taken 1.03 sec per 1 batch
# D_A loss : 0.085, D_B loss : 0.156
# 6880 img procesed out of 20000, taken 1.09 sec per 1 batch
# D_A loss : 0.046, D_B loss : 0.037
# 7520 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.052, D_B loss : 0.279
# 8160 img procesed out of 20000, taken 1.17 sec per 1 batch
# D_A loss : 0.057, D_B loss : 0.139
# 8800 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.037, D_B loss : 0.056
# 9440 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.101, D_B loss : 0.040
# 10080 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.048, D_B loss : 0.045
# 10720 img procesed out of 20000, taken 1.07 sec per 1 batch
# D_A loss : 0.097, D_B loss : 0.033
# 11360 img procesed out of 20000, taken 1.02 sec per 1 batch
# D_A loss : 0.040, D_B loss : 0.085
# 12000 img procesed out of 20000, taken 1.20 sec per 1 batch
# D_A loss : 0.045, D_B loss : 0.042
# 12640 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.021, D_B loss : 0.064
# 13280 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.015, D_B loss : 0.076
# 13920 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.106, D_B loss : 0.019
# 14560 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.029, D_B loss : 0.018
# 15200 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.033, D_B loss : 0.071
# 15840 img procesed out of 20000, taken 0.97 sec per 1 batch
# D_A loss : 0.027, D_B loss : 0.028
# 16480 img procesed out of 20000, taken 1.06 sec per 1 batch
# D_A loss : 0.016, D_B loss : 0.081
# 17120 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.033, D_B loss : 0.027
# 17760 img procesed out of 20000, taken 0.98 sec per 1 batch
# D_A loss : 0.046, D_B loss : 0.039
# 18400 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.055, D_B loss : 0.035
# 19040 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.050, D_B loss : 0.040
# 19680 img procesed out of 20000, taken 1.03 sec per 1 batch
# saving the model at the end of epoch 2, iters 2500
# End of epoch 2 / 105 	 Time Taken: 1461.05 sec
# learning rate = 0.0002000
# D_A loss : 0.075, D_B loss : 0.059
# 320 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.069, D_B loss : 0.093
# 960 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.080, D_B loss : 0.041
# 1600 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.027, D_B loss : 0.040
# 2240 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.037, D_B loss : 0.039
# 2880 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.014, D_B loss : 0.014
# 3520 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.023, D_B loss : 0.056
# 4160 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.032, D_B loss : 0.025
# 4800 img procesed out of 20000, taken 1.01 sec per 1 batch
# D_A loss : 0.151, D_B loss : 0.094
# 5440 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.021, D_B loss : 0.017
# 6080 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.038, D_B loss : 0.133
# 6720 img procesed out of 20000, taken 1.02 sec per 1 batch
# D_A loss : 0.021, D_B loss : 0.038
# 7360 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.019, D_B loss : 0.132
# 8000 img procesed out of 20000, taken 1.34 sec per 1 batch
# D_A loss : 0.263, D_B loss : 0.017
# 8640 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.020, D_B loss : 0.080
# 9280 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.037, D_B loss : 0.062
# 9920 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.013, D_B loss : 0.018
# 10560 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.019, D_B loss : 0.009
# 11200 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.040, D_B loss : 0.032
# 11840 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.016, D_B loss : 0.029
# 12480 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.004, D_B loss : 0.027
# 13120 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.022, D_B loss : 0.021
# 13760 img procesed out of 20000, taken 1.09 sec per 1 batch
# D_A loss : 0.009, D_B loss : 0.016
# 14400 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.012, D_B loss : 0.107
# 15040 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.036, D_B loss : 0.025
# 15680 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.011, D_B loss : 0.117
# 16320 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.014, D_B loss : 0.033
# 16960 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.812, D_B loss : 0.030
# 17600 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.029, D_B loss : 0.023
# 18240 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.030, D_B loss : 0.019
# 18880 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.009, D_B loss : 0.027
# 19520 img procesed out of 20000, taken 1.12 sec per 1 batch
# saving the model at the end of epoch 3, iters 3750
# End of epoch 3 / 105 	 Time Taken: 1555.99 sec
# learning rate = 0.0002000
# D_A loss : 0.008, D_B loss : 0.014
# 160 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.022, D_B loss : 0.038
# 800 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.065, D_B loss : 0.248
# 1440 img procesed out of 20000, taken 1.09 sec per 1 batch
# D_A loss : 0.011, D_B loss : 0.019
# 2080 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.007, D_B loss : 0.041
# 2720 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.013, D_B loss : 0.023
# 3360 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.012, D_B loss : 0.006
# 4000 img procesed out of 20000, taken 1.34 sec per 1 batch
# D_A loss : 0.017, D_B loss : 0.013
# 4640 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 1.422, D_B loss : 0.035
# 5280 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.086, D_B loss : 0.015
# 5920 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.023, D_B loss : 0.011
# 6560 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.034, D_B loss : 0.009
# 7200 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.058, D_B loss : 0.027
# 7840 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.014, D_B loss : 0.010
# 8480 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.013, D_B loss : 0.017
# 9120 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.007, D_B loss : 0.038
# 9760 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.008, D_B loss : 0.066
# 10400 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.007, D_B loss : 0.040
# 11040 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.015, D_B loss : 0.008
# 11680 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.008, D_B loss : 0.022
# 12320 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.018, D_B loss : 0.014
# 12960 img procesed out of 20000, taken 1.17 sec per 1 batch
# D_A loss : 0.006, D_B loss : 0.034
# 13600 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.007, D_B loss : 0.208
# 14240 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.004, D_B loss : 0.025
# 14880 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.009, D_B loss : 0.032
# 15520 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.012, D_B loss : 0.013
# 16160 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.010, D_B loss : 0.039
# 16800 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.005, D_B loss : 0.241
# 17440 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.020, D_B loss : 0.214
# 18080 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.061, D_B loss : 0.141
# 18720 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.037, D_B loss : 0.085
# 19360 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.116, D_B loss : 0.060
# 20000 img procesed out of 20000, taken 1.27 sec per 1 batch
# saving the model at the end of epoch 4, iters 5000
# End of epoch 4 / 105 	 Time Taken: 1567.98 sec
# learning rate = 0.0002000
# D_A loss : 0.017, D_B loss : 0.027
# 640 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.015, D_B loss : 0.019
# 1280 img procesed out of 20000, taken 1.30 sec per 1 batch
# D_A loss : 0.016, D_B loss : 0.051
# 1920 img procesed out of 20000, taken 1.24 sec per 1 batch
# D_A loss : 0.010, D_B loss : 0.016
# 2560 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.184, D_B loss : 0.038
# 3200 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.004, D_B loss : 0.016
# 3840 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.010, D_B loss : 0.025
# 4480 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.005, D_B loss : 0.034
# 5120 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.013, D_B loss : 0.035
# 5760 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.005, D_B loss : 0.034
# 6400 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.005, D_B loss : 0.020
# 7040 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.010, D_B loss : 0.012
# 7680 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.150, D_B loss : 0.014
# 8320 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.055, D_B loss : 0.013
# 8960 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.078, D_B loss : 0.113
# 9600 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.032, D_B loss : 0.030
# 10240 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.017, D_B loss : 0.021
# 10880 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.097, D_B loss : 0.025
# 11520 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.054, D_B loss : 0.027
# 12160 img procesed out of 20000, taken 1.09 sec per 1 batch
# D_A loss : 0.008, D_B loss : 0.025
# 12800 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.045, D_B loss : 0.014
# 13440 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.010, D_B loss : 0.033
# 14080 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.009, D_B loss : 0.033
# 14720 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.005, D_B loss : 0.011
# 15360 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.053
# 16000 img procesed out of 20000, taken 1.36 sec per 1 batch
# D_A loss : 0.003, D_B loss : 0.025
# 16640 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.004, D_B loss : 0.027
# 17280 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.012
# 17920 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.003, D_B loss : 0.021
# 18560 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.028
# 19200 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.001, D_B loss : 0.028
# 19840 img procesed out of 20000, taken 1.13 sec per 1 batch
# saving the model at the end of epoch 5, iters 6250
# End of epoch 5 / 105 	 Time Taken: 1565.41 sec
# learning rate = 0.0002000
# D_A loss : 0.003, D_B loss : 0.052
# 480 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.010, D_B loss : 0.041
# 1120 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.151
# 1760 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.069, D_B loss : 0.197
# 2400 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.003, D_B loss : 0.068
# 3040 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.003, D_B loss : 0.093
# 3680 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.004, D_B loss : 0.066
# 4320 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.003, D_B loss : 0.045
# 4960 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.013, D_B loss : 0.028
# 5600 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.037, D_B loss : 0.031
# 6240 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.008, D_B loss : 0.045
# 6880 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.010, D_B loss : 0.045
# 7520 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.016, D_B loss : 0.012
# 8160 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.034, D_B loss : 0.029
# 8800 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.004, D_B loss : 0.011
# 9440 img procesed out of 20000, taken 1.09 sec per 1 batch
# D_A loss : 0.014, D_B loss : 0.019
# 10080 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.042, D_B loss : 0.028
# 10720 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.015, D_B loss : 0.096
# 11360 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.054
# 12000 img procesed out of 20000, taken 1.37 sec per 1 batch
# D_A loss : 0.006, D_B loss : 0.058
# 12640 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.017, D_B loss : 0.023
# 13280 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.008, D_B loss : 0.042
# 13920 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.036
# 14560 img procesed out of 20000, taken 1.14 sec per 1 batch
# D_A loss : 0.005, D_B loss : 0.043
# 15200 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.003, D_B loss : 0.109
# 15840 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.007, D_B loss : 0.029
# 16480 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.001, D_B loss : 0.053
# 17120 img procesed out of 20000, taken 1.14 sec per 1 batch
# D_A loss : 0.006, D_B loss : 0.010
# 17760 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.014, D_B loss : 0.052
# 18400 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.021
# 19040 img procesed out of 20000, taken 1.14 sec per 1 batch
# D_A loss : 0.002, D_B loss : 0.021
# 19680 img procesed out of 20000, taken 1.12 sec per 1 batch
# saving the model at the end of epoch 6, iters 7500
# End of epoch 6 / 105 	 Time Taken: 1571.90 sec
# learning rate = 0.0002000
# D_A loss : 0.001, D_B loss : 0.062
# 320 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.009, D_B loss : 0.026
# 960 img procesed out of 20000, taken 1.11 sec per 1 batch
# D_A loss : 0.004, D_B loss : 0.044
# 1600 img procesed out of 20000, taken 1.10 sec per 1 batch
# D_A loss : 0.001, D_B loss : 0.102
# 2240 img procesed out of 20000, taken 1.09 sec per 1 batch
# D_A loss : 0.020, D_B loss : 0.081
# 2880 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.008, D_B loss : 0.033
# 3520 img procesed out of 20000, taken 1.13 sec per 1 batch
# D_A loss : 0.006, D_B loss : 0.039
# 4160 img procesed out of 20000, taken 1.12 sec per 1 batch
# D_A loss : 0.003, D_B loss : 0.017
# 4800 img procesed out of 20000, taken 1.13 sec per 1 batch

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
# --gpu_ids 2,3\
# --name try_second_cycle_upconv\
# --use_second_cycle\
# --gan_mode lsgan\
# --upsampling_type upconv\
# --n_blocks 9\
# --n_downsampling 2\
# --ngf_depth 32\
# --ngf_img 32\
# --ndf 64\
# --netD n_layers\
# --n_layers_D 3\
# --l_depth_A_begin 0\
# --l_depth_A_end 0\
# --l_depth_B_begin 0\
# --l_depth_B_end 0\
# --l_depth_max_iter 10000\
# --l_cycle_A_begin 10.0\
# --l_cycle_A_end 10.0\
# --l_cycle_B_begin 10.0\
# --l_cycle_B_end 10.0\
# --l_identity 0\
# --max_dataset_size 20000\
# --data_shuffle\
# --batch_size 8\
# --lr_D 0.0002\
# --lr_G 0.0001\
# --num_iter_gen 1\
# --norm instance\
# --init_type normal\
# --beta1 0.5\
# --img_freq 40\
# --loss_freq 30\
# --save_epoch_freq 3\
# --n_epochs 10\
# --n_epochs_decay 5
# Out:
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 5]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#              data_shuffle: True                          	[default: False]
#                  dataroot: /all_data/hdd/un_depth/semi/sample
#              dataset_mode: semi_cycle
#          disc_for_normals: False
#                   dropout: False
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2,3                           	[default: 2]
#                  img_freq: 40                            	[default: 1]
#                 init_type: normal
#            input_nc_depth: 1
#              input_nc_img: 3
#                   isTrain: True                          	[default: None]
#           l_cycle_A_begin: 10.0                          	[default: 1.0]
#             l_cycle_A_end: 10.0                          	[default: 1.0]
#           l_cycle_B_begin: 10.0                          	[default: 1.0]
#             l_cycle_B_end: 10.0                          	[default: 1.0]
#           l_depth_A_begin: 0.0                           	[default: 1.0]
#             l_depth_A_end: 0.0                           	[default: 1.0]
#           l_depth_B_begin: 0.0                           	[default: 1.0]
#             l_depth_B_end: 0.0                           	[default: 1.0]
#          l_depth_max_iter: 10000                         	[default: 20000]
#                l_identity: 0.0                           	[default: 1.0]
# l_reconstruction_semantic: 1.0
#                load_epoch: last
#                 load_iter: 0                             	[default: 0]
#               load_size_h: 480
#               load_size_w: 640
#                 loss_freq: 30                            	[default: 1]
#                      lr_D: 0.0002
#                      lr_G: 0.0001                        	[default: 0.0002]
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: 20000                         	[default: inf]
#              max_distance: 8000.0
#                     model: semi_cycle_gan
#                  n_blocks: 9
#            n_downsampling: 2                             	[default: 3]
#                  n_epochs: 10                            	[default: 1]
#            n_epochs_decay: 5                             	[default: 1]
#                n_layers_D: 3
#                     n_pic: 3
#                      name: try_second_cycle_upconv       	[default: test]
#                       ndf: 64
#                      netD: n_layers
#                 ngf_depth: 32                            	[default: 20]
#                   ngf_img: 32
#                      norm: instance
#              num_iter_dis: 1
#              num_iter_gen: 1
#               num_workers: 4
#             old_generator: False
#           output_nc_depth: 1
#             output_nc_img: 41
#                     phase: train
#           save_epoch_freq: 3                             	[default: 10]
#           upsampling_type: upconv
#                  use_blur: False
#          use_second_cycle: True                          	[default: False]
#              use_semantic: False
#                   verbose: False
# ----------------- End -------------------
# wandb: Tracking run with wandb version 0.9.7
# wandb: Wandb version 0.10.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Run data is saved locally in wandb/run-20201017_220028-162ui8z7
# wandb: Syncing run try_second_cycle_upconv
# wandb: ⭐️ View project at https://app.wandb.ai/maxs/depth_super_res
# wandb: 🚀 View run at https://app.wandb.ai/maxs/depth_super_res/runs/162ui8z7
# wandb: Run `wandb off` to turn off syncing.
#
# Dataset SemiCycleDataset was created
# The number of training images = 20000
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [SemiCycleGANModel] was created
# ---------- Networks initialized -------------
# [Network netG_A] Total number of parameters : 11.328 M
# [Network netG_B] Total number of parameters : 11.652 M
# [Network netD_A_depth] Total number of parameters : 2.763 M
# [Network netD_B_depth] Total number of parameters : 2.763 M
# -----------------------------------------------

# %%
# !python train.py --dataroot /all_data/hdd/un_depth/semi/sample\
# --model A2B\
# --gpu_ids 0\
# --name a2b_uptranspose\
# --gan_mode lsgan\
# --upsampling_type transpose\
# --n_blocks 9\
# --n_downsampling 3\
# --ngf_depth 20\
# --ngf_img 32\
# --ndf 64\
# --netD n_layers\
# --n_layers_D 3\
# --l_depth_A_begin 1\
# --l_depth_A_end 1\
# --l_gan_loss 2\
# --l_depth_max_iter 30000\
# --max_dataset_size 20000\
# --batch_size 7\
# --lr_D 0.0001\
# --lr_G 0.0005\
# --num_iter_gen 3\
# --norm instance\
# --init_type xavier\
# --beta1 0.5\
# --img_freq 40\
# --loss_freq 30\
# --save_epoch_freq 2\
# --n_epochs 20\
# --n_epochs_decay 5\
# # --netG_d2e unet_256\
# # --net_d2e_weights './checkpoints/depth_edge_unet_1.5_weight_binatyloss/last_netG_B.pth'\
